# %%
! gdown 1yEjicXasMGFaALQobQWgsSxQgLEtxruC
! unzip /content/ThaiDepression.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yEjicXasMGFaALQobQWgsSxQgLEtxruC
# To: /content/ThaiDepression.zip
# 100% 41.1k/41.1k [00:00<00:00, 38.4MB/s]
# Archive:  /content/ThaiDepression.zip
#   inflating: ThaiDepression/AHB_01.csv
#   inflating: ThaiDepression/AHB_02.csv
#   inflating: ThaiDepression/AHB_03.csv
#   inflating: ThaiDepression/AHB_04.csv
#   inflating: ThaiDepression/AHB_05.csv
#   inflating: ThaiDepression/AHB_06.csv
#   inflating: ThaiDepression/AHB_07.csv
#   inflating: ThaiDepression/AHB_08.csv
#   inflating: ThaiDepression/AHB_09.csv
#   inflating: ThaiDepression/AHB_10.csv
#   inflating: ThaiDepression/AHB_11.csv
#   inflating: ThaiDepression/AHB_12.csv
#   inflating: ThaiDepression/AHB_13.csv
#   inflating: ThaiDepression/All_AHB.csv

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11348299914857354930
# xla_global_id: -1
# ]

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from numpy import array
from math import sqrt
from numpy import mean
from pandas import DataFrame
from pandas import concat
from pandas import read_csv
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler, RobustScaler
from keras.preprocessing import sequence
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional, Reshape
from pandas import read_csv
from keras import Model
from keras.layers import Layer
import keras.backend as K
from keras.layers import Input, SimpleRNN
import json
import psutil 
from datetime import datetime, timezone, timedelta

# %%
file_list = os.listdir('ThaiDepression')
file_list.sort()
df_list = []
for i in range(14):
    df_list.append(pd.read_csv('ThaiDepression/' + file_list[i], index_col=0))

# %%
df_list
# Out:
# [         Chiang_Rai    Nan  Phayao  Phrae  Chiang_Mai  Mae_Hong_Son  Lampang  \
#  2016-10       10383   5315    4266   4057       15408          2002     9011
#  2016-11       10383   5315    4265   4057       15406          2002     9011
#  2016-12       10382   5315    4265   4057       15404          2002     9011
#  2017-01       10382   5655    4265   4057       15393          2002     9011
#  2017-02       10382   5655    4264   4057       15392          2002     9011
#  ...             ...    ...     ...    ...         ...           ...      ...
#  2022-03       25223   9711   10788   7988       47292          6924    17444
#  2022-04       25456   9781   10932   8095       48020          7004    17606
#  2022-05       25619   9833   10977   8122       48155          7026    17703
#  2022-06       25836   9884   11069   8161       48616          7090    17783
#  2022-07       26174  10019   11163   8250       49096          7169    17951
#
#           Lamphun   AHB_1  Country_Level
#  2016-10     3214   53656       607299.0
#  2016-11     3214   53653       611508.0
#  2016-12     3214   53650       614080.0
#  2017-01     3213   53978       620732.0
#  2017-02     3213   53976       627688.0
#  ...          ...     ...            ...
#  2022-03    12499  137869      1213727.0
#  2022-04    12650  139544      1225461.0
#  2022-05    12717  140152      1231355.0
#  2022-06    12807  141246      1239786.0
#  2022-07    12910  142732      1250291.0
#
#  [70 rows x 10 columns],
#             Tak  Phitsanulok  Phetchabun  Sukhothai  Uttaradit  AHB_2  \
#  2016-10   2558         7875        8783       7396       5982  32594
#  2016-11   2558         7895        8782       7484       5982  32701
#  2016-12   2558         7895        8781       7521       5982  32737
#  2017-01   2558         7892        8780       7605       6335  33170
#  2017-02   2558         7946        8777       7624       6492  33397
#  ...        ...          ...         ...        ...        ...    ...
#  2022-03  10165        18907       15455      12558       9036  66121
#  2022-04  10318        19057       15632      12662       9152  66821
#  2022-05  10320        19148       15671      12703       9171  67013
#  2022-06  10323        19298       15743      12779       9256  67399
#  2022-07  10547        19530       15811      12869       9385  68142
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Chai_Nat  Kamphaeng_Phet  Phichit  Nakhon_Sawan  Uthai_Thani  AHB_3  \
#  2016-10      3432            6997     5336         10476         3354  29595
#  2016-11      3439            6997     5336         10568         3354  29694
#  2016-12      3442            6996     5336         10568         3354  29696
#  2017-01      3442            6993     5336         10671         3354  29796
#  2017-02      3442            6993     5335         10685         3354  29809
#  ...           ...             ...      ...           ...          ...    ...
#  2022-03      7826           16104     9734         25026         8740  67430
#  2022-04      7886           16315     9822         25322         8785  68130
#  2022-05      7911           16374     9845         25359         8801  68290
#  2022-06      7954           16448     9904         25557         8855  68718
#  2022-07      8008           16513     9976         25736         8907  69140
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Nonthaburi  Pathum_Thani  Phra_Nakhon Si_Ayutthaya  Saraburi  \
#  2016-10        9731          8862                     10474      6518
#  2016-11        9745          8870                     10474      6518
#  2016-12        9751          9748                     10346      6517
#  2017-01        9765          9847                     10916      6515
#  2017-02        9758         10183                     10913      6513
#  ...             ...           ...                       ...       ...
#  2022-03       34826         17831                     16303     11156
#  2022-04       35225         18031                     16414     11327
#  2022-05       35361         18051                     16454     11373
#  2022-06       35606         18176                     16573     11464
#  2022-07       35923         18319                     16695     11551
#
#           Lopburi  Sing_Buri  Ang_Thong  Nakhon_Nayok   AHB_4  Country_Level
#  2016-10     7734       3388       5583          3312   55602       607299.0
#  2016-11     7734       3388       5583          3312   55624       611508.0
#  2016-12     7732       3388       5583          3311   56376       614080.0
#  2017-01     7714       3388       5686          3310   57141       620732.0
#  2017-02     7739       3388       5697          3310   57501       627688.0
#  ...          ...        ...        ...           ...     ...            ...
#  2022-03    13945       8854       8916          4820  116651      1213727.0
#  2022-04    14061       8975       8973          4868  117874      1225461.0
#  2022-05    14140       9016       8992          4884  118271      1231355.0
#  2022-06    14230       9094       9040          4923  119106      1239786.0
#  2022-07    14332       9204       9119          4963  120106      1250291.0
#
#  [70 rows x 10 columns],
#           Kanchanaburi  Nakhon_Pathom  Ratchaburi  Suphan_Buri  \
#  2016-10          8067           7603        6324         5171
#  2016-11          8238           7603        6494         5231
#  2016-12          8237           7604        6519         5230
#  2017-01          8276           7858        6640         5305
#  2017-02          8276           7872        6766         5330
#  ...               ...            ...         ...          ...
#  2022-03         14407          11406       12419        12907
#  2022-04         14536          11443       12626        13047
#  2022-05         14583          11462       12685        13079
#  2022-06         14699          11508       12815        13179
#  2022-07         14826          11564       13027        13307
#
#           Prachuap_Khiri_Khan  Phetchaburi  Samut_Songkhram  Samut_Sakhon  \
#  2016-10                 6132         4589             1507          3651
#  2016-11                 6198         4633             1522          3772
#  2016-12                 6197         4668             1522          3770
#  2017-01                 6319         4696             1720          3837
#  2017-02                 6622         4731             1725          3947
#  ...                      ...          ...              ...           ...
#  2022-03                10347         8806             2945         10015
#  2022-04                10473         8878             3128         10151
#  2022-05                10489         8899             3128         10209
#  2022-06                10575         8947             2945         10340
#  2022-07                10706         9017             3152         10458
#
#           AHB_5  Country_Level
#  2016-10  43044       607299.0
#  2016-11  43691       611508.0
#  2016-12  43747       614080.0
#  2017-01  44651       620732.0
#  2017-02  45269       627688.0
#  ...        ...            ...
#  2022-03  83252      1213727.0
#  2022-04  84282      1225461.0
#  2022-05  84534      1231355.0
#  2022-06  85008      1239786.0
#  2022-07  86057      1250291.0
#
#  [70 rows x 10 columns],
#           Chachoengsao  Prachinburi  Sa_Kaeo  Samut_Prakan  Chanthaburi  \
#  2016-10          6456         4271     6913          6004         2572
#  2016-11          6454         4271     6911          6004         2572
#  2016-12          6455         4271     6910          6002         2572
#  2017-01          6456         4271     6910          6000         3356
#  2017-02          6456         4270     6908          6034         3354
#  ...               ...          ...      ...           ...          ...
#  2022-03         17553         6847     9893         13608         7103
#  2022-04         17705         6902     9946         13773         7231
#  2022-05         17723         6917     9965         13846         7270
#  2022-06         17801         6959    10008         13953         7372
#  2022-07         17948         7018    10075         14112         7500
#
#           Chonburi  Trat  Rayong  AHB_6  Country_Level
#  2016-10      7908  1265    3357  38746       607299.0
#  2016-11      7908  1312    3357  38789       611508.0
#  2016-12      7908  1312    3357  38787       614080.0
#  2017-01      8408  1318    3356  40075       620732.0
#  2017-02      8406  1325    3355  40108       627688.0
#  ...           ...   ...     ...    ...            ...
#  2022-03     18653  3504    7466  84627      1213727.0
#  2022-04     18936  3541    7593  85627      1225461.0
#  2022-05     19009  3561    7644  85935      1231355.0
#  2022-06     19222  3591    7738  86644      1239786.0
#  2022-07     19514  3625    7837  87629      1250291.0
#
#  [70 rows x 10 columns],
#           Kalasin  Khon_Kaen  Maha_Sarakham  Roi_Et   AHB_7  Country_Level
#  2016-10     8477      19045          14203   12712   54437       607299.0
#  2016-11     8520      19234          14228   12794   54776       611508.0
#  2016-12     8532      19470          14233   12852   55087       614080.0
#  2017-01     8689      19816          14231   12925   55661       620732.0
#  2017-02     8806      20064          14231   12944   56045       627688.0
#  ...          ...        ...            ...     ...     ...            ...
#  2022-03    16722      36856          22628   23368   99574      1213727.0
#  2022-04    16809      37331          22886   23491  100517      1225461.0
#  2022-05    16862      37389          22928   23547  100726      1231355.0
#  2022-06    16962      37627          23028   23652  101269      1239786.0
#  2022-07    17039      37917          23217   23828  102001      1250291.0
#
#  [70 rows x 6 columns],
#           Bueng_Kan   Loei  Nong_Khai  Nong_Bua_Lamphu  Udon_Thani  \
#  2016-10       6450  10454       3474             6155       16452
#  2016-11       6453  10454       3474             6155       16452
#  2016-12       6453  10454       3474             6155       16451
#  2017-01       6578  10476       3479             6156       16454
#  2017-02       6576  10473       3565             6156       16498
#  ...            ...    ...        ...              ...         ...
#  2022-03       7628  14085      10383             8924       26313
#  2022-04       7663  14184      10457             8974       26313
#  2022-05       7681  14204      10491             9004       26921
#  2022-06       7711  14281      10544             9043       27021
#  2022-07       7742  14362      10623             9070       27181
#
#           Nakhon_Phanom  Sakon_Nakhon   AHB_8  Country_Level
#  2016-10           8279         14756   66020       607299.0
#  2016-11           8281         14805   66074       611508.0
#  2016-12           8575         14830   66392       614080.0
#  2017-01           8581         14940   66664       620732.0
#  2017-02           8581         14960   66809       627688.0
#  ...                ...           ...     ...            ...
#  2022-03          11933         22756  102022      1213727.0
#  2022-04          11988         22882  102461      1225461.0
#  2022-05          11998         22920  103219      1231355.0
#  2022-06          12042         23038  103680      1239786.0
#  2022-07          12146         23272  104396      1250291.0
#
#  [70 rows x 9 columns],
#           Chaiyaphum  Nakhon_Ratchasima  Buriram  Surin   AHB_9  Country_Level
#  2016-10       11333              28200    17408  14584   71525       607299.0
#  2016-11       11504              29177    17617  14599   72897       611508.0
#  2016-12       11526              29236    17745  14670   73177       614080.0
#  2017-01       11553              29379    17970  14837   73739       620732.0
#  2017-02       14161              30229    18145  15324   77859       627688.0
#  ...             ...                ...      ...    ...     ...            ...
#  2022-03       23217              61826    33541  25809  144393      1213727.0
#  2022-04       23427              62345    33727  26191  145690      1225461.0
#  2022-05       23533              62562    33815  26899  146809      1231355.0
#  2022-06       23689              63020    33994  27467  148170      1239786.0
#  2022-07       23890              63468    34396  27841  149595      1250291.0
#
#  [70 rows x 6 columns],
#           Mukdahan  Yasothon  Sisaket  Ubon_Ratchathani  Amnat_Charoen  AHB_10  \
#  2016-10      4919      6937    11902             20439           2494   46691
#  2016-11      5881      6937    12045             20438           2504   47805
#  2016-12      5890      6937    12379             20436           2510   48152
#  2017-01      6015      6937    12640             20598           2514   48704
#  2017-02      6015      6937    13100             20657           2538   49247
#  ...           ...       ...      ...               ...            ...     ...
#  2022-03      9980     12847    26734             45225           6692  101478
#  2022-04     10036     12906    26872             45617           6745  102176
#  2022-05     10053     12935    26940             45725           6776  102429
#  2022-06     10101     12973    27100             45861           6815  102850
#  2022-07     10182     13046    27298             46184           6878  103588
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Chumphon  Nakhon_Si_Thammarat  Surat_Thani  Krabi  Phang_Nga  Phuket  \
#  2016-10      3775                13009        13674   2705       2870    2036
#  2016-11      3777                13049        13684   2715       2870    2035
#  2016-12      3778                13184        13681   2716       2870    2035
#  2017-01      3804                13338        13681   2802       2868    2033
#  2017-02      3816                13420        13681   2852       2868    2043
#  ...           ...                  ...          ...    ...        ...     ...
#  2022-03      6551                26018        26693   5683       4434    4758
#  2022-04      6595                26198        26985   5744       4464    4887
#  2022-05      6615                26268        27067   5769       4479    4896
#  2022-06      6723                26478        27192   5823       4496    4944
#  2022-07      6779                26784        27389   5924       4537    5024
#
#           Ranong  AHB_11  Country_Level
#  2016-10    1447   39516       607299.0
#  2016-11    1457   39587       611508.0
#  2016-12    1485   39749       614080.0
#  2017-01    1536   40062       620732.0
#  2017-02    1543   40223       627688.0
#  ...         ...     ...            ...
#  2022-03    3835   77972      1213727.0
#  2022-04    3894   78767      1225461.0
#  2022-05    3901   78995      1231355.0
#  2022-06    3940   79596      1239786.0
#  2022-07    3976   80413      1250291.0
#
#  [70 rows x 9 columns],
#           Phatthalung  Trang  Narathiwat  Pattani  Yala  Songkhla  Satun  \
#  2016-10         6950   9535        9569     6626  3597     14123   2229
#  2016-11         6959   9626        9608     6684  3598     14231   2260
#  2016-12         6970   9682        9683     6735  3598     14330   2281
#  2017-01         6998   9718        9713     6766  3738     14637   2278
#  2017-02         7006   9934        9726     6804  3738     14682   2324
#  ...              ...    ...         ...      ...   ...       ...    ...
#  2022-03        11218  14532       14098    11015  7550     29019   5293
#  2022-04        11315  14652       14205    11083  7633     29390   5361
#  2022-05        11360  14699       14262    11126  7662     29519   5391
#  2022-06        11444  14770       14353    11199  7736     29832   5442
#  2022-07        11562  14892       14479    11267  7786     30126   5510
#
#           AHB_12  Country_Level
#  2016-10   52629       607299.0
#  2016-11   52966       611508.0
#  2016-12   53279       614080.0
#  2017-01   53848       620732.0
#  2017-02   54214       627688.0
#  ...         ...            ...
#  2022-03   92725      1213727.0
#  2022-04   93639      1225461.0
#  2022-05   94019      1231355.0
#  2022-06   94776      1239786.0
#  2022-07   95622      1250291.0
#
#  [70 rows x 9 columns],
#           Bangkok  AHB_13  Country_Level
#  2016-10    23244   23244       607299.0
#  2016-11    23251   23251       611508.0
#  2016-12    23251   23251       614080.0
#  2017-01    23243   23243       620732.0
#  2017-02    23231   23231       627688.0
#  ...          ...     ...            ...
#  2022-03    39613   39613      1213727.0
#  2022-04    39933   39933      1225461.0
#  2022-05    40963   40963      1231355.0
#  2022-06    41324   41324      1239786.0
#  2022-07    40870   40870      1250291.0
#
#  [70 rows x 3 columns],
#           Chiang_Rai    Nan  Phayao  Phrae  Chiang_Mai  Mae_Hong_Son  Lampang  \
#  2016-10       10383   5315    4266   4057       15408          2002     9011
#  2016-11       10383   5315    4265   4057       15406          2002     9011
#  2016-12       10382   5315    4265   4057       15404          2002     9011
#  2017-01       10382   5655    4265   4057       15393          2002     9011
#  2017-02       10382   5655    4264   4057       15392          2002     9011
#  ...             ...    ...     ...    ...         ...           ...      ...
#  2022-03       25223   9711   10788   7988       47292          6924    17444
#  2022-04       25456   9781   10932   8095       48020          7004    17606
#  2022-05       25619   9833   10977   8122       48155          7026    17703
#  2022-06       25836   9884   11069   8161       48616          7090    17783
#  2022-07       26174  10019   11163   8250       49096          7169    17951
#
#           Lamphun    Tak  Phitsanulok  ...  AHB_5  AHB_6   AHB_7   AHB_8  \
#  2016-10     3214   2558         7875  ...  43044  38746   54437   66020
#  2016-11     3214   2558         7895  ...  43691  38789   54776   66074
#  2016-12     3214   2558         7895  ...  43747  38787   55087   66392
#  2017-01     3213   2558         7892  ...  44651  40075   55661   66664
#  2017-02     3213   2558         7946  ...  45269  40108   56045   66809
#  ...          ...    ...          ...  ...    ...    ...     ...     ...
#  2022-03    12499  10165        18907  ...  83252  84627   99574  102022
#  2022-04    12650  10318        19057  ...  84282  85627  100517  102461
#  2022-05    12717  10320        19148  ...  84534  85935  100726  103219
#  2022-06    12807  10323        19298  ...  85008  86644  101269  103680
#  2022-07    12910  10547        19530  ...  86057  87629  102001  104396
#
#            AHB_9  AHB_10  AHB_11  AHB_12  AHB_13  Country_Level
#  2016-10   71525   46691   39516   52629   23244       607299.0
#  2016-11   72897   47805   39587   52966   23251       611508.0
#  2016-12   73177   48152   39749   53279   23251       614080.0
#  2017-01   73739   48704   40062   53848   23243       620732.0
#  2017-02   77859   49247   40223   54214   23231       627688.0
#  ...         ...     ...     ...     ...     ...            ...
#  2022-03  144393  101478   77972   92725   39613      1213727.0
#  2022-04  145690  102176   78767   93639   39933      1225461.0
#  2022-05  146809  102429   78995   94019   40963      1231355.0
#  2022-06  148170  102850   79596   94776   41324      1239786.0
#  2022-07  149595  103588   80413   95622   40870      1250291.0
#
#  [70 rows x 91 columns]]

# %%
# split a univariate sequence into samples
def uni_split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)


    # split a multivariate sequence into samples
def multi_split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)


def get_scaler(scaler):
    scalers = {
        "minmax": MinMaxScaler,
        "standard": StandardScaler,
        "maxabs": MaxAbsScaler,
        "robust": RobustScaler,
    }
    return scalers.get(scaler.lower())()


# Add attention layer to the deep learning network
class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)
 
    def build(self,input_shape):
        self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1), 
                               initializer='random_normal', trainable=True)
        self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1), 
                               initializer='zeros', trainable=True)        
        super(attention, self).build(input_shape)
 
    def call(self,x):
        # Alignment scores. Pass them through tanh function
        e = K.tanh(K.dot(x,self.W)+self.b)
        # Remove dimension of size 1
        e = K.squeeze(e, axis=-1)   
        # Compute the weights
        alpha = K.softmax(e)
        # Reshape to tensorFlow format
        alpha = K.expand_dims(alpha, axis=-1)
        # Compute the context vector
        context = x * alpha
        context = K.sum(context, axis=1)
        return context

# %%
# %matplotlib inline
# define scope of configs
AHB_list = [13]
LSTM_hidden_units = [8, 16, 32, 64, 128]
n_layer = [1, 2, 3]
n_batch = [2, 4, 8, 16, 32, 64, 128]
n_steps = [1, 2, 3, 4, 5]
patience_list = [3, 5, 7, 10]
mul_uni = ['uni','mul']
dropouts = [0.2, 0.3, 0.5]


timezone_offset = 7.0  # Bangkok Time (UTC+07:00)
tzinfo = timezone(timedelta(hours=timezone_offset))
count = 1
performance_json = []
for g in AHB_list:
    for h in patience_list:
        for a in n_steps:
            for b in dropouts:
                for c in LSTM_hidden_units:
                    for d in n_layer:
                        for e in n_batch:
                            for f in mul_uni:

                                print('PROGRESS: [ ' + str(count) + ' / ' + str(len(dropouts)*len(AHB_list)*len(n_steps)*len(LSTM_hidden_units)*len(n_layer)*len(n_batch)*len(patience_list)*len(mul_uni)) + ' ]')
                                
                                if f == 'uni':
                                    if g == 13:
                                        raw_seq = list(df_list[g]['Country_Level'])
                                        ahb = 'Country_Level'
                                    else:    
                                        raw_seq = list(df_list[g]['AHB_'+str(g+1)])
                                        ahb = 'AHB_'+str(g+1)
                                    n_features = 1
                                    scaler = get_scaler('minmax')
                                    raw_seq_arr = scaler.fit_transform(np.array(raw_seq).reshape(len(raw_seq),-1))
                                    X, y = uni_split_sequence(raw_seq_arr, a)
                                    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, train_size=0.9, shuffle=False, stratify=None)
                                    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
                                    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))
                                if f == 'mul':
                                    if g == 13:
                                        raw_seq = list(df_list[13].drop(df_list[13].columns[:77], axis=1).values)
                                        ahb = 'Country_Level'
                                        scaler_y = get_scaler('minmax')
                                        scaler_y.fit(np.array(df_list[13]['Country_Level']).reshape(len(df_list[13]['Country_Level']),-1))
                                    else:    
                                        raw_seq = list(df_list[g].drop(['Country_Level'], axis=1).values)
                                        ahb = 'AHB_'+str(g+1)
                                        scaler_y = get_scaler('minmax')
                                        scaler_y.fit(np.array(df_list[g]['AHB_'+str(g+1)]).reshape(len(df_list[13]['AHB_'+str(g+1)]),-1))
                                    n_features = len(raw_seq[0])-1
                                    scaler = get_scaler('minmax')
                                    raw_seq_arr = scaler.fit_transform(np.array(raw_seq))
                                    X, y = multi_split_sequences(raw_seq_arr, a)
                                    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, train_size=0.9, shuffle=False, stratify=None)
                                    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
                                    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

                                callback = EarlyStopping(monitor='loss', patience=h)
                                x=Input(shape=(a,n_features))
                                if d == 1:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    attention_layer = attention()(LSTM_layer)
                                if d == 2:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    LSTM_layer2 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer)
                                    attention_layer = attention()(LSTM_layer2)
                                if d ==3:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    LSTM_layer2 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer)
                                    LSTM_layer3 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer2)
                                    attention_layer = attention()(LSTM_layer3)
                                outputs=Dense(1, trainable=True, activation='tanh')(attention_layer)
                                model=Model(x,outputs)
                                model.compile(loss='mse', optimizer='adam')  
                                history = model.fit(X_train, y_train, epochs=2000, batch_size=e, verbose=0, callbacks=[callback])
                                last_epoch = len(history.history['loss']) 


                                yhat = model.predict(X_test, verbose=0)
                                mae = mean_absolute_error(y_test, yhat)
                                mse = mean_squared_error(y_test, yhat)
                                rmse = mean_squared_error(y_test, yhat, squared = False)
                                mape = mean_absolute_percentage_error(y_test, yhat)

                                yhat = model.predict(X_test, verbose=0)
                                yhat = yhat.reshape(yhat.shape[0],-1)
                                mae = mean_absolute_error(y_test, yhat)
                                mse = mean_squared_error(y_test, yhat)
                                rmse = mean_squared_error(y_test, yhat, squared = False)
                                mape = mean_absolute_percentage_error(y_test, yhat)
                                
                                if f == 'uni':
                                    yhat_inverse = scaler.inverse_transform(yhat)
                                    y_test_inverse = scaler.inverse_transform(y_test)
                                if f == 'mul':
                                    yhat_inverse = scaler_y.inverse_transform(yhat)
                                    y_test_inverse = scaler_y.inverse_transform(y_test.reshape(len(y_test),-1))


                                mae_inverse = mean_absolute_error(y_test_inverse, yhat_inverse)
                                mse_inverse = mean_squared_error(y_test_inverse, yhat_inverse)
                                rmse_inverse = mean_squared_error(y_test_inverse, yhat_inverse, squared = False)
                                mape_inverse = mean_absolute_percentage_error(y_test_inverse, yhat_inverse)

                                performance_json.append({'model': 'LSTM', 'AHB_number': ahb, 'Multi_Uni': f, \
                                                         'n_layer': d, 'LSTM_hidden_units': c, 'dropouts': b,'n_batch': e,\
                                                         'n_steps': a, 'last_epoch': last_epoch, 'patience_list': h, 'MAE_normalize': float(mae), \
                                                         'MSE_normalize': float(mse), 'RMSE_normalize': float(rmse), 'MAPE_normalize': float(mape), \
                                                         'MAE': float(mae_inverse), 'MSE': float(mse_inverse), 'RMSE': float(rmse_inverse), 'MAPE': float(mape_inverse)})
                                

                                json_formatted_str = json.dumps(performance_json[-1], indent=2)
                                print(json_formatted_str)
                                print('Percent CPU Usage: ' + str(psutil.cpu_percent()))
                                print('Percent Ram Usage: ' + str(psutil.virtual_memory()[2]))
                                print(datetime.now(tzinfo))

                                count = count + 1
# Out:
# PROGRESS: [ 1 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 1,
#   "last_epoch": 13,
#   "patience_list": 3,
#   "MAE_normalize": 0.3427109603098563,
#   "MSE_normalize": 0.11786269303936438,
#   "RMSE_normalize": 0.3433113645648282,
#   "MAPE_normalize": 0.3573099002058554,
#   "MAE": 220360.4017857143,
#   "MSE": 48728998153.426895,
#   "RMSE": 220746.45671771697,
#   "MAPE": 0.17999446009032374
# }
# Percent CPU Usage: 34.0
# Percent Ram Usage: 10.1
# 2022-10-23 00:37:42.804198+07:00
# PROGRESS: [ 2 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 1,
#   "last_epoch": 16,
#   "patience_list": 3,
#   "MAE_normalize": 0.12472191577980521,
#   "MSE_normalize": 0.015905404238533323,
#   "RMSE_normalize": 0.12611662950829808,
#   "MAPE_normalize": 0.1297021536617095,
#   "MAE": 80195.19642857143,
#   "MSE": 6575910591.305803,
#   "RMSE": 81091.98845327325,
#   "MAPE": 0.06542056627413877
# }
# Percent CPU Usage: 47.1
# Percent Ram Usage: 10.5
# 2022-10-23 00:37:48.385522+07:00
# PROGRESS: [ 3 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 1,
#   "last_epoch": 36,
#   "patience_list": 3,
#   "MAE_normalize": 0.32517609125206476,
#   "MSE_normalize": 0.10611979685200787,
#   "RMSE_normalize": 0.3257603365236595,
#   "MAPE_normalize": 0.33902100835913546,
#   "MAE": 209085.63392857142,
#   "MSE": 43874035741.36217,
#   "RMSE": 209461.29891071087,
#   "MAPE": 0.17078322806133306
# }
# Percent CPU Usage: 50.0
# Percent Ram Usage: 10.8
# 2022-10-23 00:37:54.124977+07:00
# PROGRESS: [ 4 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 1,
#   "last_epoch": 12,
#   "patience_list": 3,
#   "MAE_normalize": 0.1555632152455296,
#   "MSE_normalize": 0.024575285979795674,
#   "RMSE_normalize": 0.15676506619714634,
#   "MAPE_normalize": 0.16189119543783675,
#   "MAE": 100025.89285714286,
#   "MSE": 10160371932.464285,
#   "RMSE": 100798.67029115159,
#   "MAPE": 0.08162726041766392
# }
# Percent CPU Usage: 55.4
# Percent Ram Usage: 10.8
# 2022-10-23 00:37:58.203286+07:00
# PROGRESS: [ 5 / 12600 ]
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f925bec9560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 1,
#   "last_epoch": 32,
#   "patience_list": 3,
#   "MAE_normalize": 0.42283404424191545,
#   "MSE_normalize": 0.1792415372405783,
#   "RMSE_normalize": 0.4233692681815466,
#   "MAPE_normalize": 0.4409564480630381,
#   "MAE": 271878.8839285714,
#   "MSE": 74105377561.31082,
#   "RMSE": 272223.0290796699,
#   "MAPE": 0.22210368479065057
# }
# Percent CPU Usage: 50.8
# Percent Ram Usage: 10.8
# 2022-10-23 00:38:02.455846+07:00
# PROGRESS: [ 6 / 12600 ]
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f925be975f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Streaming output truncated to the last 5000 lines.
#   "MSE": 4492926706.560267,
#   "RMSE": 67029.29737480669,
#   "MAPE": 0.05374187413840679
# }
# Percent CPU Usage: 54.1
# Percent Ram Usage: 37.5
# 2022-10-23 23:36:29.846917+07:00
# PROGRESS: [ 10711 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 36,
#   "patience_list": 10,
#   "MAE_normalize": 0.15878284528256487,
#   "MSE_normalize": 0.025501742640098947,
#   "RMSE_normalize": 0.15969265055129792,
#   "MAPE_normalize": 0.16532300305592695,
#   "MAE": 102096.08928571429,
#   "MSE": 10543405884.908482,
#   "RMSE": 102681.08825342903,
#   "MAPE": 0.08333725567660573
# }
# Percent CPU Usage: 61.7
# Percent Ram Usage: 37.5
# 2022-10-23 23:36:36.097528+07:00
# PROGRESS: [ 10712 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 24,
#   "patience_list": 10,
#   "MAE_normalize": 0.09239887890476162,
#   "MSE_normalize": 0.008944259763481456,
#   "RMSE_normalize": 0.09457409668340193,
#   "MAPE_normalize": 0.0959027731326807,
#   "MAE": 59411.71428571428,
#   "MSE": 3697900274.325893,
#   "RMSE": 60810.363214882156,
#   "MAPE": 0.04841903632116635
# }
# Percent CPU Usage: 60.4
# Percent Ram Usage: 37.5
# 2022-10-23 23:36:42.676288+07:00
# PROGRESS: [ 10713 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 59,
#   "patience_list": 10,
#   "MAE_normalize": 0.14501980923585553,
#   "MSE_normalize": 0.02133782077387379,
#   "RMSE_normalize": 0.14607470956285962,
#   "MAPE_normalize": 0.1509349082094304,
#   "MAE": 93246.57142857143,
#   "MSE": 8821880064.477678,
#   "RMSE": 93924.8639311108,
#   "MAPE": 0.07609897680233632
# }
# Percent CPU Usage: 42.7
# Percent Ram Usage: 37.5
# 2022-10-23 23:36:50.554840+07:00
# PROGRESS: [ 10714 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 53,
#   "patience_list": 10,
#   "MAE_normalize": 0.10749410430704869,
#   "MSE_normalize": 0.012018771489035171,
#   "RMSE_normalize": 0.10963015775339909,
#   "MAPE_normalize": 0.11162698928563573,
#   "MAE": 69117.82142857143,
#   "MSE": 4969021612.361608,
#   "RMSE": 70491.2874925803,
#   "MAPE": 0.05634360670414388
# }
# Percent CPU Usage: 51.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:01.169590+07:00
# PROGRESS: [ 10715 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 69,
#   "patience_list": 10,
#   "MAE_normalize": 0.21835913527694092,
#   "MSE_normalize": 0.04807601010658753,
#   "RMSE_normalize": 0.21926242292419268,
#   "MAPE_normalize": 0.2274564273005746,
#   "MAE": 140403.17857142858,
#   "MSE": 19876483504.379463,
#   "RMSE": 140983.98314836854,
#   "MAPE": 0.1146320883682264
# }
# Percent CPU Usage: 58.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:07.134580+07:00
# PROGRESS: [ 10716 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 64,
#   "patience_list": 10,
#   "MAE_normalize": 0.08392672578608311,
#   "MSE_normalize": 0.0074001280967546535,
#   "RMSE_normalize": 0.08602399721446716,
#   "MAPE_normalize": 0.08709290992876817,
#   "MAE": 53964.21428571428,
#   "MSE": 3059499958.236607,
#   "RMSE": 55312.74679706846,
#   "MAPE": 0.0439752997904908
# }
# Percent CPU Usage: 55.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:12.999851+07:00
# PROGRESS: [ 10717 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 54,
#   "patience_list": 10,
#   "MAE_normalize": 0.24866106379714356,
#   "MSE_normalize": 0.06220616266686251,
#   "RMSE_normalize": 0.24941163298222982,
#   "MAPE_normalize": 0.25911801244188654,
#   "MAE": 159887.0892857143,
#   "MSE": 25718440155.819195,
#   "RMSE": 160369.6983716662,
#   "MAPE": 0.13056436358438936
# }
# Percent CPU Usage: 54.7
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:17.430258+07:00
# PROGRESS: [ 10718 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 57,
#   "patience_list": 10,
#   "MAE_normalize": 0.1146831226927996,
#   "MSE_normalize": 0.013542386282748448,
#   "RMSE_normalize": 0.11637175895701005,
#   "MAPE_normalize": 0.11918738222671979,
#   "MAE": 73740.33928571429,
#   "MSE": 5598948056.725447,
#   "RMSE": 74826.11881372337,
#   "MAPE": 0.060135876550662055
# }
# Percent CPU Usage: 56.0
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:21.587283+07:00
# PROGRESS: [ 10719 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 93,
#   "patience_list": 10,
#   "MAE_normalize": 0.2842927119289228,
#   "MSE_normalize": 0.0812026513995691,
#   "RMSE_normalize": 0.28496078923172763,
#   "MAPE_normalize": 0.2963246086824432,
#   "MAE": 182797.94642857142,
#   "MSE": 33572322430.194195,
#   "RMSE": 183227.5154833307,
#   "MAPE": 0.1492928526747291
# }
# Percent CPU Usage: 55.1
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:25.489984+07:00
# PROGRESS: [ 10720 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 54,
#   "patience_list": 10,
#   "MAE_normalize": 0.13355764871666434,
#   "MSE_normalize": 0.018274910605234625,
#   "RMSE_normalize": 0.13518472770706988,
#   "MAPE_normalize": 0.13886483199426825,
#   "MAE": 85876.5,
#   "MSE": 7555555017.982142,
#   "RMSE": 86922.69564378537,
#   "MAPE": 0.07004861446660268
# }
# Percent CPU Usage: 54.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:31.251531+07:00
# PROGRESS: [ 10721 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 157,
#   "patience_list": 10,
#   "MAE_normalize": 0.33023743669306554,
#   "MSE_normalize": 0.10949522025518195,
#   "RMSE_normalize": 0.3309006199075214,
#   "MAPE_normalize": 0.34426412294483283,
#   "MAE": 212340.0357142857,
#   "MSE": 45269565308.63839,
#   "RMSE": 212766.45719811757,
#   "MAPE": 0.17343291213707562
# }
# Percent CPU Usage: 52.0
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:36.030690+07:00
# PROGRESS: [ 10722 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 91,
#   "patience_list": 10,
#   "MAE_normalize": 0.10832733466626239,
#   "MSE_normalize": 0.01210234323447282,
#   "RMSE_normalize": 0.11001065055017546,
#   "MAPE_normalize": 0.1125668903040534,
#   "MAE": 69653.60714285714,
#   "MSE": 5003575961.870536,
#   "RMSE": 70735.9594680848,
#   "MAPE": 0.05679928112771459
# }
# Percent CPU Usage: 54.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:39.977008+07:00
# PROGRESS: [ 10723 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 146,
#   "patience_list": 10,
#   "MAE_normalize": 0.3125308466536761,
#   "MSE_normalize": 0.09807781015540289,
#   "RMSE_normalize": 0.3131737699032326,
#   "MAPE_normalize": 0.32579841976548946,
#   "MAE": 200954.83035714287,
#   "MSE": 40549161554.32198,
#   "RMSE": 201368.22379492247,
#   "MAPE": 0.16413204140064494
# }
# Percent CPU Usage: 53.5
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:44.524570+07:00
# PROGRESS: [ 10724 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 69,
#   "patience_list": 10,
#   "MAE_normalize": 0.23699637520995484,
#   "MSE_normalize": 0.05667140392166473,
#   "RMSE_normalize": 0.2380575643025542,
#   "MAPE_normalize": 0.24684422874754727,
#   "MAE": 152386.75,
#   "MSE": 23430145733.830357,
#   "RMSE": 153069.08810674466,
#   "MAPE": 0.12440951651974254
# }
# Percent CPU Usage: 53.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:48.296933+07:00
# PROGRESS: [ 10725 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.12558434390000958,
#   "MSE_normalize": 0.016048553356974464,
#   "RMSE_normalize": 0.12668288501993655,
#   "MAPE_normalize": 0.13066361068967045,
#   "MAE": 80749.73214285714,
#   "MSE": 6635093859.078125,
#   "RMSE": 81456.08546375234,
#   "MAPE": 0.06588931742466035
# }
# Percent CPU Usage: 61.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:37:56.958897+07:00
# PROGRESS: [ 10726 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 43,
#   "patience_list": 10,
#   "MAE_normalize": 0.09490159278938773,
#   "MSE_normalize": 0.009459113170765381,
#   "RMSE_normalize": 0.0972579722735642,
#   "MAPE_normalize": 0.098483634058724,
#   "MAE": 61020.96428571428,
#   "MSE": 3910762906.785714,
#   "RMSE": 62536.09283274511,
#   "MAPE": 0.04972630583297801
# }
# Percent CPU Usage: 62.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:38:11.050206+07:00
# PROGRESS: [ 10727 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 39,
#   "patience_list": 10,
#   "MAE_normalize": 0.14644603769099035,
#   "MSE_normalize": 0.021762692335316,
#   "RMSE_normalize": 0.14752183680837222,
#   "MAPE_normalize": 0.15241672438346962,
#   "MAE": 94163.625,
#   "MSE": 8997538954.984375,
#   "RMSE": 94855.35807208982,
#   "MAPE": 0.07684673083770402
# }
# Percent CPU Usage: 45.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:38:21.057539+07:00
# PROGRESS: [ 10728 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 27,
#   "patience_list": 10,
#   "MAE_normalize": 0.1025950027091265,
#   "MSE_normalize": 0.010980870127392064,
#   "RMSE_normalize": 0.10478964704297875,
#   "MAPE_normalize": 0.10651661094816231,
#   "MAE": 65967.75,
#   "MSE": 4539914482.625,
#   "RMSE": 67378.88751400546,
#   "MAPE": 0.05376992194090847
# }
# Percent CPU Usage: 47.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:38:31.958722+07:00
# PROGRESS: [ 10729 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.1725116171734776,
#   "MSE_normalize": 0.03003834738520266,
#   "RMSE_normalize": 0.173315744770066,
#   "MAPE_normalize": 0.1796706955835299,
#   "MAE": 110923.57142857143,
#   "MSE": 12419011875.125,
#   "RMSE": 111440.62039994662,
#   "MAPE": 0.09055635169652436
# }
# Percent CPU Usage: 45.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:38:44.244206+07:00
# PROGRESS: [ 10730 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 51,
#   "patience_list": 10,
#   "MAE_normalize": 0.08935148926122873,
#   "MSE_normalize": 0.008428083599317501,
#   "RMSE_normalize": 0.09180459465254177,
#   "MAPE_normalize": 0.09269325894508852,
#   "MAE": 57452.30357142857,
#   "MSE": 3484496960.457589,
#   "RMSE": 59029.62781906717,
#   "MAPE": 0.04681039277128982
# }
# Percent CPU Usage: 57.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:38:53.286908+07:00
# PROGRESS: [ 10731 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 81,
#   "patience_list": 10,
#   "MAE_normalize": 0.1502330528565918,
#   "MSE_normalize": 0.022851325220066894,
#   "RMSE_normalize": 0.1511665479531331,
#   "MAPE_normalize": 0.1564014541462738,
#   "MAE": 96598.66071428571,
#   "MSE": 9447624438.274553,
#   "RMSE": 97198.89113706263,
#   "MAPE": 0.07884494033718503
# }
# Percent CPU Usage: 55.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:01.292809+07:00
# PROGRESS: [ 10732 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 56,
#   "patience_list": 10,
#   "MAE_normalize": 0.12495253466539046,
#   "MSE_normalize": 0.016052191820050177,
#   "RMSE_normalize": 0.12669724472162044,
#   "MAPE_normalize": 0.12987675224978137,
#   "MAE": 80343.48214285714,
#   "MSE": 6636597606.895089,
#   "RMSE": 81465.31536117128,
#   "MAPE": 0.06552500544007796
# }
# Percent CPU Usage: 56.0
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:09.445104+07:00
# PROGRESS: [ 10733 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 69,
#   "patience_list": 10,
#   "MAE_normalize": 0.3207402880430324,
#   "MSE_normalize": 0.10330555068386445,
#   "RMSE_normalize": 0.32141180856319584,
#   "MAPE_normalize": 0.33435095499649325,
#   "MAE": 206233.4375,
#   "MSE": 42710513748.71038,
#   "RMSE": 206665.22142999867,
#   "MAPE": 0.16844202996240623
# }
# Percent CPU Usage: 49.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:19.180790+07:00
# PROGRESS: [ 10734 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 83,
#   "patience_list": 10,
#   "MAE_normalize": 0.1672751192263297,
#   "MSE_normalize": 0.02845988987148258,
#   "RMSE_normalize": 0.16870059238628232,
#   "MAPE_normalize": 0.1740483545471697,
#   "MAE": 107556.58928571429,
#   "MSE": 11766425789.220982,
#   "RMSE": 108473.15699849886,
#   "MAPE": 0.08776489168916912
# }
# Percent CPU Usage: 51.0
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:27.607202+07:00
# PROGRESS: [ 10735 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 142,
#   "patience_list": 10,
#   "MAE_normalize": 0.3201464810269322,
#   "MSE_normalize": 0.10293695866054564,
#   "RMSE_normalize": 0.3208379009103283,
#   "MAPE_normalize": 0.3337223928479777,
#   "MAE": 205851.61607142858,
#   "MSE": 42558119894.84766,
#   "RMSE": 206296.19457190105,
#   "MAPE": 0.16812775206465183
# }
# Percent CPU Usage: 49.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:36.060915+07:00
# PROGRESS: [ 10736 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 171,
#   "patience_list": 10,
#   "MAE_normalize": 0.18086198097298148,
#   "MSE_normalize": 0.03317565954586256,
#   "RMSE_normalize": 0.1821418665377693,
#   "MAPE_normalize": 0.1882475544509045,
#   "MAE": 116292.78571428571,
#   "MSE": 13716096120.9375,
#   "RMSE": 117115.7381436735,
#   "MAPE": 0.09490926427380787
# }
# Percent CPU Usage: 55.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:44.061520+07:00
# PROGRESS: [ 10737 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 109,
#   "patience_list": 10,
#   "MAE_normalize": 0.32657701327801775,
#   "MSE_normalize": 0.10709713110476955,
#   "RMSE_normalize": 0.32725698022314137,
#   "MAPE_normalize": 0.34043707463334216,
#   "MAE": 209986.4017857143,
#   "MSE": 44278097785.39118,
#   "RMSE": 210423.61508488344,
#   "MAPE": 0.17150771215885943
# }
# Percent CPU Usage: 53.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:39:53.366987+07:00
# PROGRESS: [ 10738 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 89,
#   "patience_list": 10,
#   "MAE_normalize": 0.22523872892176428,
#   "MSE_normalize": 0.0512343356102429,
#   "RMSE_normalize": 0.22635002896011058,
#   "MAPE_normalize": 0.23456690650648285,
#   "MAE": 144826.69642857142,
#   "MSE": 21182256809.77009,
#   "RMSE": 145541.2546660571,
#   "MAPE": 0.11822953252232142
# }
# Percent CPU Usage: 53.5
# Percent Ram Usage: 37.6
# 2022-10-23 23:40:00.127623+07:00
# PROGRESS: [ 10739 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.14601802525180752,
#   "MSE_normalize": 0.021597241297839912,
#   "RMSE_normalize": 0.14695999897196485,
#   "MAPE_normalize": 0.15200435655834402,
#   "MAE": 93888.41071428571,
#   "MSE": 8929133780.91741,
#   "RMSE": 94494.0938943668,
#   "MAPE": 0.07663051472254519
# }
# Percent CPU Usage: 62.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:40:12.130084+07:00
# PROGRESS: [ 10740 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 31,
#   "patience_list": 10,
#   "MAE_normalize": 0.10237451661315308,
#   "MSE_normalize": 0.01098770661271303,
#   "RMSE_normalize": 0.10482226200914112,
#   "MAPE_normalize": 0.1062513826067142,
#   "MAE": 65826.0,
#   "MSE": 4542744145.1875,
#   "RMSE": 67399.88238259396,
#   "MAPE": 0.053645180895121776
# }
# Percent CPU Usage: 62.5
# Percent Ram Usage: 37.6
# 2022-10-23 23:40:30.776456+07:00
# PROGRESS: [ 10741 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 43,
#   "patience_list": 10,
#   "MAE_normalize": 0.1400031076737915,
#   "MSE_normalize": 0.019897019042439686,
#   "RMSE_normalize": 0.14105679367701396,
#   "MAPE_normalize": 0.14570513685683548,
#   "MAE": 90020.875,
#   "MSE": 8226197350.033483,
#   "RMSE": 90698.38670027975,
#   "MAPE": 0.07346432237140477
# }
# Percent CPU Usage: 59.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:40:42.183887+07:00
# PROGRESS: [ 10742 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 33,
#   "patience_list": 10,
#   "MAE_normalize": 0.07130060576371809,
#   "MSE_normalize": 0.005600911340716094,
#   "RMSE_normalize": 0.07483923663905248,
#   "MAPE_normalize": 0.0737931511949005,
#   "MAE": 45845.732142857145,
#   "MSE": 2315634586.975446,
#   "RMSE": 48121.041000537865,
#   "MAPE": 0.03730956687082297
# }
# Percent CPU Usage: 57.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:40:57.501533+07:00
# PROGRESS: [ 10743 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 52,
#   "patience_list": 10,
#   "MAE_normalize": 0.12227866178581717,
#   "MSE_normalize": 0.015266369488246228,
#   "RMSE_normalize": 0.12355715069653488,
#   "MAPE_normalize": 0.12717944934953884,
#   "MAE": 78624.17857142857,
#   "MSE": 6311704030.633928,
#   "RMSE": 79446.23358368808,
#   "MAPE": 0.06414357736572576
# }
# Percent CPU Usage: 58.5
# Percent Ram Usage: 37.6
# 2022-10-23 23:41:10.684013+07:00
# PROGRESS: [ 10744 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 46,
#   "patience_list": 10,
#   "MAE_normalize": 0.07857400729657245,
#   "MSE_normalize": 0.006670609828441333,
#   "RMSE_normalize": 0.08167380135907311,
#   "MAPE_normalize": 0.08140245036985098,
#   "MAE": 50522.42857142857,
#   "MSE": 2757885368.928571,
#   "RMSE": 52515.57263258748,
#   "MAPE": 0.04113617705570543
# }
# Percent CPU Usage: 58.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:41:22.368654+07:00
# PROGRESS: [ 10745 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 73,
#   "patience_list": 10,
#   "MAE_normalize": 0.12906809063299388,
#   "MSE_normalize": 0.01703308720391753,
#   "RMSE_normalize": 0.13051087006038053,
#   "MAPE_normalize": 0.1342219614680827,
#   "MAE": 82989.73214285714,
#   "MSE": 7042134483.622767,
#   "RMSE": 83917.42657888627,
#   "MAPE": 0.06770028643548719
# }
# Percent CPU Usage: 50.1
# Percent Ram Usage: 37.6
# 2022-10-23 23:41:37.507671+07:00
# PROGRESS: [ 10746 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 70,
#   "patience_list": 10,
#   "MAE_normalize": 0.08214748456479144,
#   "MSE_normalize": 0.007253112487822733,
#   "RMSE_normalize": 0.08516520702624243,
#   "MAPE_normalize": 0.0851290042104967,
#   "MAE": 52820.17857142857,
#   "MSE": 2998718065.888393,
#   "RMSE": 54760.55209627084,
#   "MAPE": 0.043013235921308776
# }
# Percent CPU Usage: 57.0
# Percent Ram Usage: 37.5
# 2022-10-23 23:41:49.477359+07:00
# PROGRESS: [ 10747 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 98,
#   "patience_list": 10,
#   "MAE_normalize": 0.1936461043936968,
#   "MSE_normalize": 0.03781581900783537,
#   "RMSE_normalize": 0.19446289879520817,
#   "MAPE_normalize": 0.20170892710950936,
#   "MAE": 124512.875,
#   "MSE": 15634518412.533482,
#   "RMSE": 125038.06785348804,
#   "MAPE": 0.1016572235304354
# }
# Percent CPU Usage: 55.5
# Percent Ram Usage: 37.5
# 2022-10-23 23:41:59.603673+07:00
# PROGRESS: [ 10748 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 145,
#   "patience_list": 10,
#   "MAE_normalize": 0.09335257876601563,
#   "MSE_normalize": 0.009215115745747687,
#   "RMSE_normalize": 0.09599539439862564,
#   "MAPE_normalize": 0.09683384824452361,
#   "MAE": 60024.94642857143,
#   "MSE": 3809884435.444196,
#   "RMSE": 61724.26131955081,
#   "MAPE": 0.04890391525425825
# }
# Percent CPU Usage: 49.7
# Percent Ram Usage: 37.5
# 2022-10-23 23:42:15.152789+07:00
# PROGRESS: [ 10749 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 136,
#   "patience_list": 10,
#   "MAE_normalize": 0.32843583521503383,
#   "MSE_normalize": 0.10832147776843233,
#   "RMSE_normalize": 0.32912228391349063,
#   "MAPE_normalize": 0.34237359253586375,
#   "MAE": 211181.61607142858,
#   "MSE": 44784292631.951454,
#   "RMSE": 211622.99646293512,
#   "MAPE": 0.1724836078470278
# }
# Percent CPU Usage: 54.1
# Percent Ram Usage: 37.5
# 2022-10-23 23:42:26.005537+07:00
# PROGRESS: [ 10750 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 93,
#   "patience_list": 10,
#   "MAE_normalize": 0.2776295086894819,
#   "MSE_normalize": 0.07766662160860684,
#   "RMSE_normalize": 0.27868731870791474,
#   "MAPE_normalize": 0.28922577647575526,
#   "MAE": 178513.54464285713,
#   "MSE": 32110385294.728237,
#   "RMSE": 179193.7088592349,
#   "MAPE": 0.14575480914255798
# }
# Percent CPU Usage: 53.9
# Percent Ram Usage: 37.5
# 2022-10-23 23:42:38.522262+07:00
# PROGRESS: [ 10751 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 111,
#   "patience_list": 10,
#   "MAE_normalize": 0.3605637605428798,
#   "MSE_normalize": 0.13051792224087266,
#   "RMSE_normalize": 0.3612726425303647,
#   "MAPE_normalize": 0.37588553715705614,
#   "MAE": 231839.5892857143,
#   "MSE": 53961150909.688614,
#   "RMSE": 232295.39579959094,
#   "MAPE": 0.18936133320813497
# }
# Percent CPU Usage: 54.0
# Percent Ram Usage: 37.5
# 2022-10-23 23:42:48.506839+07:00
# PROGRESS: [ 10752 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 8,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 109,
#   "patience_list": 10,
#   "MAE_normalize": 0.2501648804698774,
#   "MSE_normalize": 0.0630867015738171,
#   "RMSE_normalize": 0.25117066224743906,
#   "MAPE_normalize": 0.2605966015126516,
#   "MAE": 160854.0,
#   "MSE": 26082478762.357143,
#   "RMSE": 161500.7082410388,
#   "MAPE": 0.13133151855470362
# }
# Percent CPU Usage: 54.5
# Percent Ram Usage: 37.5
# 2022-10-23 23:42:58.661238+07:00
# PROGRESS: [ 10753 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 28,
#   "patience_list": 10,
#   "MAE_normalize": 0.12327267993178712,
#   "MSE_normalize": 0.015491169523874606,
#   "RMSE_normalize": 0.12446352688187252,
#   "MAPE_normalize": 0.12823379861637924,
#   "MAE": 79263.32142857143,
#   "MSE": 6404644715.34375,
#   "RMSE": 80029.02420587014,
#   "MAPE": 0.06467020537835332
# }
# Percent CPU Usage: 45.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:43:06.357610+07:00
# PROGRESS: [ 10754 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 35,
#   "patience_list": 10,
#   "MAE_normalize": 0.09231298009669102,
#   "MSE_normalize": 0.008930209793383383,
#   "RMSE_normalize": 0.0944997872663393,
#   "MAPE_normalize": 0.09581171037148185,
#   "MAE": 59356.5,
#   "MSE": 3692093712.611607,
#   "RMSE": 60762.60126600578,
#   "MAPE": 0.04837357259904642
# }
# Percent CPU Usage: 58.6
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:16.912379+07:00
# PROGRESS: [ 10755 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 40,
#   "patience_list": 10,
#   "MAE_normalize": 0.14502157183035105,
#   "MSE_normalize": 0.02129106818093378,
#   "RMSE_normalize": 0.1459145920767823,
#   "MAPE_normalize": 0.15097825594723452,
#   "MAE": 93247.71428571429,
#   "MSE": 8802552500.459822,
#   "RMSE": 93821.9190832282,
#   "MAPE": 0.07611043168602656
# }
# Percent CPU Usage: 53.8
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:22.233122+07:00
# PROGRESS: [ 10756 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 55,
#   "patience_list": 10,
#   "MAE_normalize": 0.09599020350661622,
#   "MSE_normalize": 0.009539742952961257,
#   "RMSE_normalize": 0.097671607711562,
#   "MAPE_normalize": 0.09971586715674662,
#   "MAE": 61720.92857142857,
#   "MSE": 3944099018.09375,
#   "RMSE": 62802.06221211012,
#   "MAPE": 0.05032270810349595
# }
# Percent CPU Usage: 51.9
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:30.471836+07:00
# PROGRESS: [ 10757 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 65,
#   "patience_list": 10,
#   "MAE_normalize": 0.13460663937501569,
#   "MSE_normalize": 0.018378175909943565,
#   "RMSE_normalize": 0.13556613113142812,
#   "MAPE_normalize": 0.14010206642362197,
#   "MAE": 86550.98214285714,
#   "MSE": 7598247572.412947,
#   "RMSE": 87167.9274298348,
#   "MAPE": 0.07063595647567207
# }
# Percent CPU Usage: 42.0
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:38.826050+07:00
# PROGRESS: [ 10758 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 51,
#   "patience_list": 10,
#   "MAE_normalize": 0.1031921901600804,
#   "MSE_normalize": 0.011026297215660568,
#   "RMSE_normalize": 0.10500617703573713,
#   "MAPE_normalize": 0.10719628461311344,
#   "MAE": 66351.73214285714,
#   "MSE": 4558695147.533483,
#   "RMSE": 67518.10977458923,
#   "MAPE": 0.05409803100753645
# }
# Percent CPU Usage: 50.4
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:44.578658+07:00
# PROGRESS: [ 10759 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 85,
#   "patience_list": 10,
#   "MAE_normalize": 0.169842231672161,
#   "MSE_normalize": 0.029139540088936978,
#   "RMSE_normalize": 0.17070307580397306,
#   "MAPE_normalize": 0.17686976636798804,
#   "MAE": 109207.19642857143,
#   "MSE": 12047413994.372768,
#   "RMSE": 109760.71243561045,
#   "MAPE": 0.08914986669939408
# }
# Percent CPU Usage: 57.9
# Percent Ram Usage: 37.7
# 2022-10-23 23:43:49.297701+07:00
# PROGRESS: [ 10760 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 57,
#   "patience_list": 10,
#   "MAE_normalize": 0.11013854952200143,
#   "MSE_normalize": 0.012498159453069368,
#   "RMSE_normalize": 0.11179516739586452,
#   "MAPE_normalize": 0.11445820801047872,
#   "MAE": 70818.19642857143,
#   "MSE": 5167221885.975447,
#   "RMSE": 71883.39089091058,
#   "MAPE": 0.057751312274585964
# }
# Percent CPU Usage: 55.1
# Percent Ram Usage: 37.6
# 2022-10-23 23:43:55.635741+07:00
# PROGRESS: [ 10761 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 105,
#   "patience_list": 10,
#   "MAE_normalize": 0.3273993530171361,
#   "MSE_normalize": 0.10763458896146116,
#   "RMSE_normalize": 0.32807710825575925,
#   "MAPE_normalize": 0.3412961112785525,
#   "MAE": 210515.1607142857,
#   "MSE": 44500304056.8337,
#   "RMSE": 210950.95177987157,
#   "MAPE": 0.17194003441575806
# }
# Percent CPU Usage: 56.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:43:59.921244+07:00
# PROGRESS: [ 10762 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 51,
#   "patience_list": 10,
#   "MAE_normalize": 0.11018473460675311,
#   "MSE_normalize": 0.012476795268431665,
#   "RMSE_normalize": 0.11169957595457408,
#   "MAPE_normalize": 0.11453146402130475,
#   "MAE": 70847.875,
#   "MSE": 5158385657.046875,
#   "RMSE": 71821.9023491224,
#   "MAPE": 0.057781894685523603
# }
# Percent CPU Usage: 53.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:04.153209+07:00
# PROGRESS: [ 10763 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 125,
#   "patience_list": 10,
#   "MAE_normalize": 0.2625344791310277,
#   "MSE_normalize": 0.06927108811290428,
#   "RMSE_normalize": 0.2631940123044297,
#   "MAPE_normalize": 0.2736276046749828,
#   "MAE": 168807.57142857142,
#   "MSE": 28639350110.410713,
#   "RMSE": 169231.64630296166,
#   "MAPE": 0.13786223698582942
# }
# Percent CPU Usage: 49.4
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:08.613955+07:00
# PROGRESS: [ 10764 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 56,
#   "patience_list": 10,
#   "MAE_normalize": 0.137447839522372,
#   "MSE_normalize": 0.019285951347714776,
#   "RMSE_normalize": 0.13887386848401242,
#   "MAPE_normalize": 0.1429584223835701,
#   "MAE": 88377.85714285714,
#   "MSE": 7973557456.790178,
#   "RMSE": 89294.77844079226,
#   "MAPE": 0.07210136036561336
# }
# Percent CPU Usage: 52.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:12.321744+07:00
# PROGRESS: [ 10765 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 84,
#   "patience_list": 10,
#   "MAE_normalize": 0.2949271938358137,
#   "MSE_normalize": 0.08729534263218224,
#   "RMSE_normalize": 0.2954578525478418,
#   "MAPE_normalize": 0.3074837533847405,
#   "MAE": 189635.83035714287,
#   "MSE": 36091275149.64007,
#   "RMSE": 189977.0384800228,
#   "MAPE": 0.15489632688794733
# }
# Percent CPU Usage: 47.9
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:16.689814+07:00
# PROGRESS: [ 10766 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 73,
#   "patience_list": 10,
#   "MAE_normalize": 0.16019077511175364,
#   "MSE_normalize": 0.026069211621773034,
#   "RMSE_normalize": 0.16145962845793072,
#   "MAPE_normalize": 0.16669948701248063,
#   "MAE": 103001.375,
#   "MSE": 10778018678.359375,
#   "RMSE": 103817.2369038946,
#   "MAPE": 0.08405354475871309
# }
# Percent CPU Usage: 48.7
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:22.824648+07:00
# PROGRESS: [ 10767 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 22,
#   "patience_list": 10,
#   "MAE_normalize": 0.12915022583349436,
#   "MSE_normalize": 0.01694063839045978,
#   "RMSE_normalize": 0.13015620765241964,
#   "MAPE_normalize": 0.1344022538148484,
#   "MAE": 83042.57142857143,
#   "MSE": 7003917206.285714,
#   "RMSE": 83689.40916439614,
#   "MAPE": 0.06776743946968082
# }
# Percent CPU Usage: 61.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:31.195773+07:00
# PROGRESS: [ 10768 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 38,
#   "patience_list": 10,
#   "MAE_normalize": 0.08560813875539987,
#   "MSE_normalize": 0.007692504995476859,
#   "RMSE_normalize": 0.08770692672461429,
#   "MAPE_normalize": 0.08884319683547777,
#   "MAE": 55045.357142857145,
#   "MSE": 3180380402.830357,
#   "RMSE": 56394.86149313922,
#   "MAPE": 0.04485771248238661
# }
# Percent CPU Usage: 64.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:44.637591+07:00
# PROGRESS: [ 10769 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.11317220455238822,
#   "MSE_normalize": 0.01309082264187256,
#   "RMSE_normalize": 0.11441513292337059,
#   "MAPE_normalize": 0.11769605489444133,
#   "MAE": 72768.80357142857,
#   "MSE": 5412249798.502233,
#   "RMSE": 73567.99438955933,
#   "MAPE": 0.05936358409447145
# }
# Percent CPU Usage: 46.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:44:54.871999+07:00
# PROGRESS: [ 10770 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 32,
#   "patience_list": 10,
#   "MAE_normalize": 0.07483777528831961,
#   "MSE_normalize": 0.005988713925123054,
#   "RMSE_normalize": 0.07738678133326811,
#   "MAPE_normalize": 0.07757681726198128,
#   "MAE": 48120.107142857145,
#   "MSE": 2475967504.549107,
#   "RMSE": 49759.09469181596,
#   "MAPE": 0.039191605720884516
# }
# Percent CPU Usage: 50.7
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:07.650621+07:00
# PROGRESS: [ 10771 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 55,
#   "patience_list": 10,
#   "MAE_normalize": 0.11550772740841937,
#   "MSE_normalize": 0.013591816366729903,
#   "RMSE_normalize": 0.1165839455788399,
#   "MAPE_normalize": 0.1201651202922995,
#   "MAE": 74270.53571428571,
#   "MSE": 5619382143.004464,
#   "RMSE": 74962.53826415207,
#   "MAPE": 0.06059885763198743
# }
# Percent CPU Usage: 49.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:18.146641+07:00
# PROGRESS: [ 10772 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 36,
#   "patience_list": 10,
#   "MAE_normalize": 0.07805791622231009,
#   "MSE_normalize": 0.006481663242814402,
#   "RMSE_normalize": 0.08050877742715015,
#   "MAPE_normalize": 0.08093932169954206,
#   "MAE": 50190.58928571428,
#   "MSE": 2679767872.631696,
#   "RMSE": 51766.4744079766,
#   "MAPE": 0.04088412674127913
# }
# Percent CPU Usage: 57.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:25.956596+07:00
# PROGRESS: [ 10773 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 71,
#   "patience_list": 10,
#   "MAE_normalize": 0.12123535911356724,
#   "MSE_normalize": 0.014954423410691765,
#   "RMSE_normalize": 0.12228827994003254,
#   "MAPE_normalize": 0.12614052712179405,
#   "MAE": 77953.375,
#   "MSE": 6182738748.935267,
#   "RMSE": 78630.39328996942,
#   "MAPE": 0.06360803145205694
# }
# Percent CPU Usage: 57.8
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:33.752177+07:00
# PROGRESS: [ 10774 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 65,
#   "patience_list": 10,
#   "MAE_normalize": 0.0769183520487479,
#   "MSE_normalize": 0.006262054975435559,
#   "RMSE_normalize": 0.0791331471346588,
#   "MAPE_normalize": 0.07978241236024072,
#   "MAE": 49457.892857142855,
#   "MSE": 2588976026.044643,
#   "RMSE": 50881.98134943885,
#   "MAPE": 0.04029354804509947
# }
# Percent CPU Usage: 56.1
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:44.163050+07:00
# PROGRESS: [ 10775 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 90,
#   "patience_list": 10,
#   "MAE_normalize": 0.1636796989338841,
#   "MSE_normalize": 0.02703616501981295,
#   "RMSE_normalize": 0.16442677707664574,
#   "MAPE_normalize": 0.1704773043589248,
#   "MAE": 105244.75,
#   "MSE": 11177799958.044643,
#   "RMSE": 105725.11507699882,
#   "MAPE": 0.0859215257274734
# }
# Percent CPU Usage: 52.5
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:52.313815+07:00
# PROGRESS: [ 10776 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 72,
#   "patience_list": 10,
#   "MAE_normalize": 0.10018130410399781,
#   "MSE_normalize": 0.010436040521712946,
#   "RMSE_normalize": 0.10215694064385908,
#   "MAPE_normalize": 0.10403540112372892,
#   "MAE": 64415.767857142855,
#   "MSE": 4314661894.881697,
#   "RMSE": 65686.08600671604,
#   "MAPE": 0.05251118717701982
# }
# Percent CPU Usage: 49.2
# Percent Ram Usage: 37.6
# 2022-10-23 23:45:59.940757+07:00
# PROGRESS: [ 10777 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 94,
#   "patience_list": 10,
#   "MAE_normalize": 0.2378356511831386,
#   "MSE_normalize": 0.05688160954355888,
#   "RMSE_normalize": 0.23849865732024336,
#   "MAPE_normalize": 0.24785871512517504,
#   "MAE": 152926.42857142858,
#   "MSE": 23517061561.17857,
#   "RMSE": 153352.73574729136,
#   "MAPE": 0.12488568048199464
# }
# Percent CPU Usage: 53.7
# Percent Ram Usage: 37.6
# 2022-10-23 23:46:08.674908+07:00
# PROGRESS: [ 10778 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 57,
#   "patience_list": 10,
#   "MAE_normalize": 0.19443924637182444,
#   "MSE_normalize": 0.038324966384184915,
#   "RMSE_normalize": 0.195767633648121,
#   "MAPE_normalize": 0.20239096207168328,
#   "MAE": 125022.875,
#   "MSE": 15845023258.497768,
#   "RMSE": 125877.0164029072,
#   "MAPE": 0.10203707414283458
# }
# Percent CPU Usage: 52.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:46:15.726627+07:00
# PROGRESS: [ 10779 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 90,
#   "patience_list": 10,
#   "MAE_normalize": 0.26269479859557493,
#   "MSE_normalize": 0.06939100563108204,
#   "RMSE_normalize": 0.26342172581448564,
#   "MAPE_normalize": 0.2737674297801514,
#   "MAE": 168910.64285714287,
#   "MSE": 28688924813.61607,
#   "RMSE": 169378.05292781017,
#   "MAPE": 0.137939502668989
# }
# Percent CPU Usage: 54.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:46:22.848153+07:00
# PROGRESS: [ 10780 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 62,
#   "patience_list": 10,
#   "MAE_normalize": 0.16761208131314348,
#   "MSE_normalize": 0.028583310980224725,
#   "RMSE_normalize": 0.16906599593124788,
#   "MAPE_normalize": 0.17439317145580602,
#   "MAE": 107773.21428571429,
#   "MSE": 11817444952.428572,
#   "RMSE": 108708.07215855026,
#   "MAPE": 0.08794018100793498
# }
# Percent CPU Usage: 52.6
# Percent Ram Usage: 37.6
# 2022-10-23 23:46:29.773631+07:00
# PROGRESS: [ 10781 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 45,
#   "patience_list": 10,
#   "MAE_normalize": 0.14880765886648387,
#   "MSE_normalize": 0.02235383582781617,
#   "RMSE_normalize": 0.14951199225418732,
#   "MAPE_normalize": 0.1549802654029897,
#   "MAE": 95682.14285714286,
#   "MSE": 9241942332.897322,
#   "RMSE": 96135.02136525129,
#   "MAPE": 0.07811276700377211
# }
# Percent CPU Usage: 57.7
# Percent Ram Usage: 37.6
# 2022-10-23 23:46:48.487285+07:00
# PROGRESS: [ 10782 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.11056248330049177,
#   "MSE_normalize": 0.012649667676290095,
#   "RMSE_normalize": 0.11247074142322569,
#   "MAPE_normalize": 0.1148580705789253,
#   "MAE": 71090.78571428571,
#   "MSE": 5229861585.745536,
#   "RMSE": 72317.78194708088,
#   "MAPE": 0.05796328864138156
# }
# Percent CPU Usage: 56.3
# Percent Ram Usage: 37.6
# 2022-10-23 23:47:07.229041+07:00
# PROGRESS: [ 10783 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 16,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
# ...
#   "RMSE_normalize": 0.04339753571014329,
#   "MAPE_normalize": 0.03933955390532621,
#   "MAE": 24592.303571428572,
#   "MSE": 778645918.4397322,
#   "RMSE": 27904.22760872861,
#   "MAPE": 0.019951471545139206
# }
# Percent CPU Usage: 52.2
# Percent Ram Usage: 37.6
# 2022-10-24 00:03:40.935736+07:00
# PROGRESS: [ 10893 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 37,
#   "patience_list": 10,
#   "MAE_normalize": 0.19401166819505353,
#   "MSE_normalize": 0.03778298336690563,
#   "RMSE_normalize": 0.19437845396778325,
#   "MAPE_normalize": 0.20226458053461235,
#   "MAE": 124747.94642857143,
#   "MSE": 15620946426.716518,
#   "RMSE": 124983.78465511644,
#   "MAPE": 0.10189347669074725
# }
# Percent CPU Usage: 67.1
# Percent Ram Usage: 37.6
# 2022-10-24 00:03:56.391539+07:00
# PROGRESS: [ 10894 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 16,
#   "patience_list": 10,
#   "MAE_normalize": 0.10421673439912459,
#   "MSE_normalize": 0.011106374857825313,
#   "RMSE_normalize": 0.10538678692239038,
#   "MAPE_normalize": 0.10837773410547033,
#   "MAE": 67010.5,
#   "MSE": 4591801674.75,
#   "RMSE": 67762.83402241969,
#   "MAPE": 0.054664843892435984
# }
# Percent CPU Usage: 44.2
# Percent Ram Usage: 37.6
# 2022-10-24 00:04:12.386911+07:00
# PROGRESS: [ 10895 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 69,
#   "patience_list": 10,
#   "MAE_normalize": 0.17386775056635656,
#   "MSE_normalize": 0.030370975405189283,
#   "RMSE_normalize": 0.17427270413116702,
#   "MAPE_normalize": 0.18122940813888438,
#   "MAE": 111795.58928571429,
#   "MSE": 12556540735.497768,
#   "RMSE": 112055.97144060538,
#   "MAPE": 0.09130534339341265
# }
# Percent CPU Usage: 59.3
# Percent Ram Usage: 37.6
# 2022-10-24 00:04:27.569863+07:00
# PROGRESS: [ 10896 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.08945930554867816,
#   "MSE_normalize": 0.00826308785481882,
#   "RMSE_normalize": 0.09090152834149061,
#   "MAPE_normalize": 0.09295212898059843,
#   "MAE": 57521.58928571428,
#   "MSE": 3416276971.390625,
#   "RMSE": 58448.92617825091,
#   "MAPE": 0.046904095858738136
# }
# Percent CPU Usage: 60.9
# Percent Ram Usage: 37.6
# 2022-10-24 00:04:39.171555+07:00
# PROGRESS: [ 10897 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 77,
#   "patience_list": 10,
#   "MAE_normalize": 0.16543863200120587,
#   "MSE_normalize": 0.027478868454687062,
#   "RMSE_normalize": 0.16576751326688552,
#   "MAPE_normalize": 0.1724693642818023,
#   "MAE": 106375.73214285714,
#   "MSE": 11360831039.939732,
#   "RMSE": 106587.1992311447,
#   "MAPE": 0.08688543438713014
# }
# Percent CPU Usage: 53.4
# Percent Ram Usage: 37.6
# 2022-10-24 00:04:55.322200+07:00
# PROGRESS: [ 10898 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.07196218326092792,
#   "MSE_normalize": 0.005455314583193096,
#   "RMSE_normalize": 0.07386010142961555,
#   "MAPE_normalize": 0.07466418861360478,
#   "MAE": 46271.125,
#   "MSE": 2255439804.725446,
#   "RMSE": 47491.470862939655,
#   "MAPE": 0.03770298164859746
# }
# Percent CPU Usage: 58.1
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:03.729801+07:00
# PROGRESS: [ 10899 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 27,
#   "patience_list": 10,
#   "MAE_normalize": 0.12077772316593105,
#   "MSE_normalize": 0.014829075116627927,
#   "RMSE_normalize": 0.12177468996728313,
#   "MAPE_normalize": 0.12567621725428516,
#   "MAE": 77659.08928571429,
#   "MSE": 6130910660.676339,
#   "RMSE": 78300.13193268795,
#   "MAPE": 0.06337090822271131
# }
# Percent CPU Usage: 49.7
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:11.793567+07:00
# PROGRESS: [ 10900 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 38,
#   "patience_list": 10,
#   "MAE_normalize": 0.07969815089703632,
#   "MSE_normalize": 0.006612991354758653,
#   "RMSE_normalize": 0.08132030100017248,
#   "MAPE_normalize": 0.08275716583941344,
#   "MAE": 51245.267857142855,
#   "MSE": 2734066326.354911,
#   "RMSE": 52288.300090506964,
#   "MAPE": 0.04177292352965662
# }
# Percent CPU Usage: 57.2
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:21.699134+07:00
# PROGRESS: [ 10901 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 47,
#   "patience_list": 10,
#   "MAE_normalize": 0.17114324779852122,
#   "MSE_normalize": 0.029508439382528617,
#   "RMSE_normalize": 0.1717802066087028,
#   "MAPE_normalize": 0.1782976753694922,
#   "MAE": 110043.75,
#   "MSE": 12199933703.71875,
#   "RMSE": 110453.31006230076,
#   "MAPE": 0.08985130085359898
# }
# Percent CPU Usage: 56.6
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:30.289920+07:00
# PROGRESS: [ 10902 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 47,
#   "patience_list": 10,
#   "MAE_normalize": 0.06437124224050729,
#   "MSE_normalize": 0.004434516543271772,
#   "RMSE_normalize": 0.06659216578000578,
#   "MAPE_normalize": 0.06672430965523982,
#   "MAE": 41390.17857142857,
#   "MSE": 1833399564.4017856,
#   "RMSE": 42818.21533415172,
#   "MAPE": 0.03370965135884663
# }
# Percent CPU Usage: 55.2
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:38.602824+07:00
# PROGRESS: [ 10903 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.1641147872958967,
#   "MSE_normalize": 0.027259103209610107,
#   "RMSE_normalize": 0.16510331071668463,
#   "MAPE_normalize": 0.17086119701381625,
#   "MAE": 105524.48214285714,
#   "MSE": 11269966001.154018,
#   "RMSE": 106160.09608677839,
#   "MAPE": 0.08613234941614437
# }
# Percent CPU Usage: 53.9
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:45.449133+07:00
# PROGRESS: [ 10904 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.06836610731738979,
#   "MSE_normalize": 0.005060986921909413,
#   "RMSE_normalize": 0.07114061373019924,
#   "MAPE_normalize": 0.0708189393623826,
#   "MAE": 43958.857142857145,
#   "MSE": 2092407373.9017856,
#   "RMSE": 45742.83959158838,
#   "MAPE": 0.03578995150732872
# }
# Percent CPU Usage: 53.1
# Percent Ram Usage: 37.6
# 2022-10-24 00:05:54.546834+07:00
# PROGRESS: [ 10905 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 28,
#   "patience_list": 10,
#   "MAE_normalize": 0.12951917858465403,
#   "MSE_normalize": 0.01712053988706177,
#   "RMSE_normalize": 0.13084548095773796,
#   "MAPE_normalize": 0.13471564117271087,
#   "MAE": 83279.80357142857,
#   "MSE": 7078295259.854911,
#   "RMSE": 84132.60521257446,
#   "MAPE": 0.06794315853969868
# }
# Percent CPU Usage: 52.9
# Percent Ram Usage: 37.6
# 2022-10-24 00:06:01.562476+07:00
# PROGRESS: [ 10906 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.05470858852183141,
#   "MSE_normalize": 0.003388668091275001,
#   "RMSE_normalize": 0.058212267532496975,
#   "MAPE_normalize": 0.056549457688179906,
#   "MAE": 35177.19642857143,
#   "MSE": 1401007354.3950894,
#   "RMSE": 37430.03278645491,
#   "MAPE": 0.028609280261777222
# }
# Percent CPU Usage: 53.3
# Percent Ram Usage: 37.6
# 2022-10-24 00:06:08.618564+07:00
# PROGRESS: [ 10907 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 62,
#   "patience_list": 10,
#   "MAE_normalize": 0.1910764800378357,
#   "MSE_normalize": 0.03666067021865347,
#   "RMSE_normalize": 0.19146976319683864,
#   "MAPE_normalize": 0.19918954930714694,
#   "MAE": 122860.64285714286,
#   "MSE": 15156939282.915178,
#   "RMSE": 123113.52193368191,
#   "MAPE": 0.10034813697647614
# }
# Percent CPU Usage: 72.9
# Percent Ram Usage: 37.6
# 2022-10-24 00:06:38.947958+07:00
# PROGRESS: [ 10908 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 13,
#   "patience_list": 10,
#   "MAE_normalize": 0.07931792435306484,
#   "MSE_normalize": 0.006618235041157375,
#   "RMSE_normalize": 0.08135253555456877,
#   "MAPE_normalize": 0.08230340069621822,
#   "MAE": 51000.767857142855,
#   "MSE": 2736232481.011161,
#   "RMSE": 52309.00955869037,
#   "MAPE": 0.04155867566866544
# }
# Percent CPU Usage: 49.9
# Percent Ram Usage: 37.6
# 2022-10-24 00:06:57.465955+07:00
# PROGRESS: [ 10909 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 42,
#   "patience_list": 10,
#   "MAE_normalize": 0.21733163635050573,
#   "MSE_normalize": 0.04730310884550336,
#   "RMSE_normalize": 0.21749277883530607,
#   "MAPE_normalize": 0.22672519604040983,
#   "MAE": 139742.48214285713,
#   "MSE": 19556930546.006695,
#   "RMSE": 139846.09592693925,
#   "MAPE": 0.11417862664191873
# }
# Percent CPU Usage: 66.5
# Percent Ram Usage: 37.6
# 2022-10-24 00:07:12.234994+07:00
# PROGRESS: [ 10910 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 14,
#   "patience_list": 10,
#   "MAE_normalize": 0.09344672855991298,
#   "MSE_normalize": 0.009026925098722908,
#   "RMSE_normalize": 0.0950101315582865,
#   "MAPE_normalize": 0.0970857101299674,
#   "MAE": 60085.5,
#   "MSE": 3732080405.964286,
#   "RMSE": 61090.75548693342,
#   "MAPE": 0.04899234331113077
# }
# Percent CPU Usage: 54.5
# Percent Ram Usage: 37.6
# 2022-10-24 00:07:27.355748+07:00
# PROGRESS: [ 10911 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 26,
#   "patience_list": 10,
#   "MAE_normalize": 0.10369153232916085,
#   "MSE_normalize": 0.010994180432928843,
#   "RMSE_normalize": 0.10485313744914285,
#   "MAPE_normalize": 0.10783205506577838,
#   "MAE": 66672.80357142857,
#   "MSE": 4545416940.551339,
#   "RMSE": 67419.70736032113,
#   "MAPE": 0.05438946730714682
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 37.6
# 2022-10-24 00:07:40.448409+07:00
# PROGRESS: [ 10912 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 19,
#   "patience_list": 10,
#   "MAE_normalize": 0.09128783981119908,
#   "MSE_normalize": 0.008614315219603026,
#   "RMSE_normalize": 0.0928133353543715,
#   "MAPE_normalize": 0.09484313172863716,
#   "MAE": 58697.357142857145,
#   "MSE": 3561492732.508929,
#   "RMSE": 59678.243376534876,
#   "MAPE": 0.047860578863316634
# }
# Percent CPU Usage: 57.4
# Percent Ram Usage: 37.6
# 2022-10-24 00:07:53.518201+07:00
# PROGRESS: [ 10913 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.12240164319788731,
#   "MSE_normalize": 0.015190461345682577,
#   "RMSE_normalize": 0.12324958963697435,
#   "MAPE_normalize": 0.1274052406274473,
#   "MAE": 78703.26785714286,
#   "MSE": 6280323493.377233,
#   "RMSE": 79248.49205743433,
#   "MAPE": 0.06423291808245044
# }
# Percent CPU Usage: 53.5
# Percent Ram Usage: 37.6
# 2022-10-24 00:08:06.727625+07:00
# PROGRESS: [ 10914 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 35,
#   "patience_list": 10,
#   "MAE_normalize": 0.08099359824658466,
#   "MSE_normalize": 0.006845560149853591,
#   "RMSE_normalize": 0.08273790032296922,
#   "MAPE_normalize": 0.08408828414969553,
#   "MAE": 52078.232142857145,
#   "MSE": 2830219548.470982,
#   "RMSE": 53199.80778603417,
#   "MAPE": 0.042448359079578786
# }
# Percent CPU Usage: 49.2
# Percent Ram Usage: 37.7
# 2022-10-24 00:08:20.101946+07:00
# PROGRESS: [ 10915 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.1151145751714809,
#   "MSE_normalize": 0.013490048130932686,
#   "RMSE_normalize": 0.11614666646500314,
#   "MAPE_normalize": 0.1197649752005706,
#   "MAE": 74017.76785714286,
#   "MSE": 5577310177.939733,
#   "RMSE": 74681.39110876105,
#   "MAPE": 0.06039487153663207
# }
# Percent CPU Usage: 47.7
# Percent Ram Usage: 37.9
# 2022-10-24 00:08:35.636561+07:00
# PROGRESS: [ 10916 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 50,
#   "patience_list": 10,
#   "MAE_normalize": 0.06730416542122367,
#   "MSE_normalize": 0.00484069530404845,
#   "RMSE_normalize": 0.06957510549074612,
#   "MAPE_normalize": 0.0697703327635873,
#   "MAE": 43276.03571428572,
#   "MSE": 2001330113.2455356,
#   "RMSE": 44736.22819645768,
#   "MAPE": 0.03524704578034994
# }
# Percent CPU Usage: 59.0
# Percent Ram Usage: 37.8
# 2022-10-24 00:08:46.489230+07:00
# PROGRESS: [ 10917 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 27,
#   "patience_list": 10,
#   "MAE_normalize": 0.25712913825512956,
#   "MSE_normalize": 0.06645725452671641,
#   "RMSE_normalize": 0.25779304592388913,
#   "MAPE_normalize": 0.26798644295442625,
#   "MAE": 165331.9642857143,
#   "MSE": 27475996384.35268,
#   "RMSE": 165758.85009360037,
#   "MAPE": 0.13502189073821372
# }
# Percent CPU Usage: 51.2
# Percent Ram Usage: 37.8
# 2022-10-24 00:08:56.789633+07:00
# PROGRESS: [ 10918 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "Country_Level",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 22,
#   "patience_list": 10,
#   "MAE_normalize": 0.14737879929202968,
#   "MSE_normalize": 0.02206432616775861,
#   "RMSE_normalize": 0.14854065493244134,
#   "MAPE_normalize": 0.1533684250023874,
#   "MAE": 94763.35714285714,
#   "MSE": 9122240990.5,
#   "RMSE": 95510.42346519044,
#   "MAPE": 0.0773313489982432
# }
# Percent CPU Usage: 50.2
# Percent Ram Usage: 37.7
# 2022-10-24 00:09:09.413343+07:00
# PROGRESS: [ 10919 / 12600 ]

# %%
name = "all_performance_LSTM_with_Attention_AHBC"
json.dump(performance_json, open(name + ".json","w"))
df_json = pd.read_json('/content/' + name + '.json')
df_json.to_csv('/content/' + name + '.csv', index=False)
! cp /content/all_performance_LSTM_with_Attention_AHB1.csv /content/drive/MyDrive/Depression

# %%
df_json
