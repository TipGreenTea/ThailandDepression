# %%
! gdown 1yEjicXasMGFaALQobQWgsSxQgLEtxruC
! unzip /content/ThaiDepression.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yEjicXasMGFaALQobQWgsSxQgLEtxruC
# To: /content/ThaiDepression.zip
# 100% 41.1k/41.1k [00:00<00:00, 37.2MB/s]
# Archive:  /content/ThaiDepression.zip
#   inflating: ThaiDepression/AHB_01.csv
#   inflating: ThaiDepression/AHB_02.csv
#   inflating: ThaiDepression/AHB_03.csv
#   inflating: ThaiDepression/AHB_04.csv
#   inflating: ThaiDepression/AHB_05.csv
#   inflating: ThaiDepression/AHB_06.csv
#   inflating: ThaiDepression/AHB_07.csv
#   inflating: ThaiDepression/AHB_08.csv
#   inflating: ThaiDepression/AHB_09.csv
#   inflating: ThaiDepression/AHB_10.csv
#   inflating: ThaiDepression/AHB_11.csv
#   inflating: ThaiDepression/AHB_12.csv
#   inflating: ThaiDepression/AHB_13.csv
#   inflating: ThaiDepression/All_AHB.csv

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14964354424884675218
# xla_global_id: -1
# ]

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from numpy import array
from math import sqrt
from numpy import mean
from pandas import DataFrame
from pandas import concat
from pandas import read_csv
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler, RobustScaler
from keras.preprocessing import sequence
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional, Reshape
from pandas import read_csv
from keras import Model
from keras.layers import Layer
import keras.backend as K
from keras.layers import Input, SimpleRNN
import json
import psutil 
from datetime import datetime, timezone, timedelta

# %%
file_list = os.listdir('ThaiDepression')
file_list.sort()
df_list = []
for i in range(14):
    df_list.append(pd.read_csv('ThaiDepression/' + file_list[i], index_col=0))

# %%
df_list
# Out:
# [         Chiang_Rai    Nan  Phayao  Phrae  Chiang_Mai  Mae_Hong_Son  Lampang  \
#  2016-10       10383   5315    4266   4057       15408          2002     9011
#  2016-11       10383   5315    4265   4057       15406          2002     9011
#  2016-12       10382   5315    4265   4057       15404          2002     9011
#  2017-01       10382   5655    4265   4057       15393          2002     9011
#  2017-02       10382   5655    4264   4057       15392          2002     9011
#  ...             ...    ...     ...    ...         ...           ...      ...
#  2022-03       25223   9711   10788   7988       47292          6924    17444
#  2022-04       25456   9781   10932   8095       48020          7004    17606
#  2022-05       25619   9833   10977   8122       48155          7026    17703
#  2022-06       25836   9884   11069   8161       48616          7090    17783
#  2022-07       26174  10019   11163   8250       49096          7169    17951
#
#           Lamphun   AHB_1  Country_Level
#  2016-10     3214   53656       607299.0
#  2016-11     3214   53653       611508.0
#  2016-12     3214   53650       614080.0
#  2017-01     3213   53978       620732.0
#  2017-02     3213   53976       627688.0
#  ...          ...     ...            ...
#  2022-03    12499  137869      1213727.0
#  2022-04    12650  139544      1225461.0
#  2022-05    12717  140152      1231355.0
#  2022-06    12807  141246      1239786.0
#  2022-07    12910  142732      1250291.0
#
#  [70 rows x 10 columns],
#             Tak  Phitsanulok  Phetchabun  Sukhothai  Uttaradit  AHB_2  \
#  2016-10   2558         7875        8783       7396       5982  32594
#  2016-11   2558         7895        8782       7484       5982  32701
#  2016-12   2558         7895        8781       7521       5982  32737
#  2017-01   2558         7892        8780       7605       6335  33170
#  2017-02   2558         7946        8777       7624       6492  33397
#  ...        ...          ...         ...        ...        ...    ...
#  2022-03  10165        18907       15455      12558       9036  66121
#  2022-04  10318        19057       15632      12662       9152  66821
#  2022-05  10320        19148       15671      12703       9171  67013
#  2022-06  10323        19298       15743      12779       9256  67399
#  2022-07  10547        19530       15811      12869       9385  68142
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Chai_Nat  Kamphaeng_Phet  Phichit  Nakhon_Sawan  Uthai_Thani  AHB_3  \
#  2016-10      3432            6997     5336         10476         3354  29595
#  2016-11      3439            6997     5336         10568         3354  29694
#  2016-12      3442            6996     5336         10568         3354  29696
#  2017-01      3442            6993     5336         10671         3354  29796
#  2017-02      3442            6993     5335         10685         3354  29809
#  ...           ...             ...      ...           ...          ...    ...
#  2022-03      7826           16104     9734         25026         8740  67430
#  2022-04      7886           16315     9822         25322         8785  68130
#  2022-05      7911           16374     9845         25359         8801  68290
#  2022-06      7954           16448     9904         25557         8855  68718
#  2022-07      8008           16513     9976         25736         8907  69140
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Nonthaburi  Pathum_Thani  Phra_Nakhon Si_Ayutthaya  Saraburi  \
#  2016-10        9731          8862                     10474      6518
#  2016-11        9745          8870                     10474      6518
#  2016-12        9751          9748                     10346      6517
#  2017-01        9765          9847                     10916      6515
#  2017-02        9758         10183                     10913      6513
#  ...             ...           ...                       ...       ...
#  2022-03       34826         17831                     16303     11156
#  2022-04       35225         18031                     16414     11327
#  2022-05       35361         18051                     16454     11373
#  2022-06       35606         18176                     16573     11464
#  2022-07       35923         18319                     16695     11551
#
#           Lopburi  Sing_Buri  Ang_Thong  Nakhon_Nayok   AHB_4  Country_Level
#  2016-10     7734       3388       5583          3312   55602       607299.0
#  2016-11     7734       3388       5583          3312   55624       611508.0
#  2016-12     7732       3388       5583          3311   56376       614080.0
#  2017-01     7714       3388       5686          3310   57141       620732.0
#  2017-02     7739       3388       5697          3310   57501       627688.0
#  ...          ...        ...        ...           ...     ...            ...
#  2022-03    13945       8854       8916          4820  116651      1213727.0
#  2022-04    14061       8975       8973          4868  117874      1225461.0
#  2022-05    14140       9016       8992          4884  118271      1231355.0
#  2022-06    14230       9094       9040          4923  119106      1239786.0
#  2022-07    14332       9204       9119          4963  120106      1250291.0
#
#  [70 rows x 10 columns],
#           Kanchanaburi  Nakhon_Pathom  Ratchaburi  Suphan_Buri  \
#  2016-10          8067           7603        6324         5171
#  2016-11          8238           7603        6494         5231
#  2016-12          8237           7604        6519         5230
#  2017-01          8276           7858        6640         5305
#  2017-02          8276           7872        6766         5330
#  ...               ...            ...         ...          ...
#  2022-03         14407          11406       12419        12907
#  2022-04         14536          11443       12626        13047
#  2022-05         14583          11462       12685        13079
#  2022-06         14699          11508       12815        13179
#  2022-07         14826          11564       13027        13307
#
#           Prachuap_Khiri_Khan  Phetchaburi  Samut_Songkhram  Samut_Sakhon  \
#  2016-10                 6132         4589             1507          3651
#  2016-11                 6198         4633             1522          3772
#  2016-12                 6197         4668             1522          3770
#  2017-01                 6319         4696             1720          3837
#  2017-02                 6622         4731             1725          3947
#  ...                      ...          ...              ...           ...
#  2022-03                10347         8806             2945         10015
#  2022-04                10473         8878             3128         10151
#  2022-05                10489         8899             3128         10209
#  2022-06                10575         8947             2945         10340
#  2022-07                10706         9017             3152         10458
#
#           AHB_5  Country_Level
#  2016-10  43044       607299.0
#  2016-11  43691       611508.0
#  2016-12  43747       614080.0
#  2017-01  44651       620732.0
#  2017-02  45269       627688.0
#  ...        ...            ...
#  2022-03  83252      1213727.0
#  2022-04  84282      1225461.0
#  2022-05  84534      1231355.0
#  2022-06  85008      1239786.0
#  2022-07  86057      1250291.0
#
#  [70 rows x 10 columns],
#           Chachoengsao  Prachinburi  Sa_Kaeo  Samut_Prakan  Chanthaburi  \
#  2016-10          6456         4271     6913          6004         2572
#  2016-11          6454         4271     6911          6004         2572
#  2016-12          6455         4271     6910          6002         2572
#  2017-01          6456         4271     6910          6000         3356
#  2017-02          6456         4270     6908          6034         3354
#  ...               ...          ...      ...           ...          ...
#  2022-03         17553         6847     9893         13608         7103
#  2022-04         17705         6902     9946         13773         7231
#  2022-05         17723         6917     9965         13846         7270
#  2022-06         17801         6959    10008         13953         7372
#  2022-07         17948         7018    10075         14112         7500
#
#           Chonburi  Trat  Rayong  AHB_6  Country_Level
#  2016-10      7908  1265    3357  38746       607299.0
#  2016-11      7908  1312    3357  38789       611508.0
#  2016-12      7908  1312    3357  38787       614080.0
#  2017-01      8408  1318    3356  40075       620732.0
#  2017-02      8406  1325    3355  40108       627688.0
#  ...           ...   ...     ...    ...            ...
#  2022-03     18653  3504    7466  84627      1213727.0
#  2022-04     18936  3541    7593  85627      1225461.0
#  2022-05     19009  3561    7644  85935      1231355.0
#  2022-06     19222  3591    7738  86644      1239786.0
#  2022-07     19514  3625    7837  87629      1250291.0
#
#  [70 rows x 10 columns],
#           Kalasin  Khon_Kaen  Maha_Sarakham  Roi_Et   AHB_7  Country_Level
#  2016-10     8477      19045          14203   12712   54437       607299.0
#  2016-11     8520      19234          14228   12794   54776       611508.0
#  2016-12     8532      19470          14233   12852   55087       614080.0
#  2017-01     8689      19816          14231   12925   55661       620732.0
#  2017-02     8806      20064          14231   12944   56045       627688.0
#  ...          ...        ...            ...     ...     ...            ...
#  2022-03    16722      36856          22628   23368   99574      1213727.0
#  2022-04    16809      37331          22886   23491  100517      1225461.0
#  2022-05    16862      37389          22928   23547  100726      1231355.0
#  2022-06    16962      37627          23028   23652  101269      1239786.0
#  2022-07    17039      37917          23217   23828  102001      1250291.0
#
#  [70 rows x 6 columns],
#           Bueng_Kan   Loei  Nong_Khai  Nong_Bua_Lamphu  Udon_Thani  \
#  2016-10       6450  10454       3474             6155       16452
#  2016-11       6453  10454       3474             6155       16452
#  2016-12       6453  10454       3474             6155       16451
#  2017-01       6578  10476       3479             6156       16454
#  2017-02       6576  10473       3565             6156       16498
#  ...            ...    ...        ...              ...         ...
#  2022-03       7628  14085      10383             8924       26313
#  2022-04       7663  14184      10457             8974       26313
#  2022-05       7681  14204      10491             9004       26921
#  2022-06       7711  14281      10544             9043       27021
#  2022-07       7742  14362      10623             9070       27181
#
#           Nakhon_Phanom  Sakon_Nakhon   AHB_8  Country_Level
#  2016-10           8279         14756   66020       607299.0
#  2016-11           8281         14805   66074       611508.0
#  2016-12           8575         14830   66392       614080.0
#  2017-01           8581         14940   66664       620732.0
#  2017-02           8581         14960   66809       627688.0
#  ...                ...           ...     ...            ...
#  2022-03          11933         22756  102022      1213727.0
#  2022-04          11988         22882  102461      1225461.0
#  2022-05          11998         22920  103219      1231355.0
#  2022-06          12042         23038  103680      1239786.0
#  2022-07          12146         23272  104396      1250291.0
#
#  [70 rows x 9 columns],
#           Chaiyaphum  Nakhon_Ratchasima  Buriram  Surin   AHB_9  Country_Level
#  2016-10       11333              28200    17408  14584   71525       607299.0
#  2016-11       11504              29177    17617  14599   72897       611508.0
#  2016-12       11526              29236    17745  14670   73177       614080.0
#  2017-01       11553              29379    17970  14837   73739       620732.0
#  2017-02       14161              30229    18145  15324   77859       627688.0
#  ...             ...                ...      ...    ...     ...            ...
#  2022-03       23217              61826    33541  25809  144393      1213727.0
#  2022-04       23427              62345    33727  26191  145690      1225461.0
#  2022-05       23533              62562    33815  26899  146809      1231355.0
#  2022-06       23689              63020    33994  27467  148170      1239786.0
#  2022-07       23890              63468    34396  27841  149595      1250291.0
#
#  [70 rows x 6 columns],
#           Mukdahan  Yasothon  Sisaket  Ubon_Ratchathani  Amnat_Charoen  AHB_10  \
#  2016-10      4919      6937    11902             20439           2494   46691
#  2016-11      5881      6937    12045             20438           2504   47805
#  2016-12      5890      6937    12379             20436           2510   48152
#  2017-01      6015      6937    12640             20598           2514   48704
#  2017-02      6015      6937    13100             20657           2538   49247
#  ...           ...       ...      ...               ...            ...     ...
#  2022-03      9980     12847    26734             45225           6692  101478
#  2022-04     10036     12906    26872             45617           6745  102176
#  2022-05     10053     12935    26940             45725           6776  102429
#  2022-06     10101     12973    27100             45861           6815  102850
#  2022-07     10182     13046    27298             46184           6878  103588
#
#           Country_Level
#  2016-10       607299.0
#  2016-11       611508.0
#  2016-12       614080.0
#  2017-01       620732.0
#  2017-02       627688.0
#  ...                ...
#  2022-03      1213727.0
#  2022-04      1225461.0
#  2022-05      1231355.0
#  2022-06      1239786.0
#  2022-07      1250291.0
#
#  [70 rows x 7 columns],
#           Chumphon  Nakhon_Si_Thammarat  Surat_Thani  Krabi  Phang_Nga  Phuket  \
#  2016-10      3775                13009        13674   2705       2870    2036
#  2016-11      3777                13049        13684   2715       2870    2035
#  2016-12      3778                13184        13681   2716       2870    2035
#  2017-01      3804                13338        13681   2802       2868    2033
#  2017-02      3816                13420        13681   2852       2868    2043
#  ...           ...                  ...          ...    ...        ...     ...
#  2022-03      6551                26018        26693   5683       4434    4758
#  2022-04      6595                26198        26985   5744       4464    4887
#  2022-05      6615                26268        27067   5769       4479    4896
#  2022-06      6723                26478        27192   5823       4496    4944
#  2022-07      6779                26784        27389   5924       4537    5024
#
#           Ranong  AHB_11  Country_Level
#  2016-10    1447   39516       607299.0
#  2016-11    1457   39587       611508.0
#  2016-12    1485   39749       614080.0
#  2017-01    1536   40062       620732.0
#  2017-02    1543   40223       627688.0
#  ...         ...     ...            ...
#  2022-03    3835   77972      1213727.0
#  2022-04    3894   78767      1225461.0
#  2022-05    3901   78995      1231355.0
#  2022-06    3940   79596      1239786.0
#  2022-07    3976   80413      1250291.0
#
#  [70 rows x 9 columns],
#           Phatthalung  Trang  Narathiwat  Pattani  Yala  Songkhla  Satun  \
#  2016-10         6950   9535        9569     6626  3597     14123   2229
#  2016-11         6959   9626        9608     6684  3598     14231   2260
#  2016-12         6970   9682        9683     6735  3598     14330   2281
#  2017-01         6998   9718        9713     6766  3738     14637   2278
#  2017-02         7006   9934        9726     6804  3738     14682   2324
#  ...              ...    ...         ...      ...   ...       ...    ...
#  2022-03        11218  14532       14098    11015  7550     29019   5293
#  2022-04        11315  14652       14205    11083  7633     29390   5361
#  2022-05        11360  14699       14262    11126  7662     29519   5391
#  2022-06        11444  14770       14353    11199  7736     29832   5442
#  2022-07        11562  14892       14479    11267  7786     30126   5510
#
#           AHB_12  Country_Level
#  2016-10   52629       607299.0
#  2016-11   52966       611508.0
#  2016-12   53279       614080.0
#  2017-01   53848       620732.0
#  2017-02   54214       627688.0
#  ...         ...            ...
#  2022-03   92725      1213727.0
#  2022-04   93639      1225461.0
#  2022-05   94019      1231355.0
#  2022-06   94776      1239786.0
#  2022-07   95622      1250291.0
#
#  [70 rows x 9 columns],
#           Bangkok  AHB_13  Country_Level
#  2016-10    23244   23244       607299.0
#  2016-11    23251   23251       611508.0
#  2016-12    23251   23251       614080.0
#  2017-01    23243   23243       620732.0
#  2017-02    23231   23231       627688.0
#  ...          ...     ...            ...
#  2022-03    39613   39613      1213727.0
#  2022-04    39933   39933      1225461.0
#  2022-05    40963   40963      1231355.0
#  2022-06    41324   41324      1239786.0
#  2022-07    40870   40870      1250291.0
#
#  [70 rows x 3 columns],
#           Chiang_Rai    Nan  Phayao  Phrae  Chiang_Mai  Mae_Hong_Son  Lampang  \
#  2016-10       10383   5315    4266   4057       15408          2002     9011
#  2016-11       10383   5315    4265   4057       15406          2002     9011
#  2016-12       10382   5315    4265   4057       15404          2002     9011
#  2017-01       10382   5655    4265   4057       15393          2002     9011
#  2017-02       10382   5655    4264   4057       15392          2002     9011
#  ...             ...    ...     ...    ...         ...           ...      ...
#  2022-03       25223   9711   10788   7988       47292          6924    17444
#  2022-04       25456   9781   10932   8095       48020          7004    17606
#  2022-05       25619   9833   10977   8122       48155          7026    17703
#  2022-06       25836   9884   11069   8161       48616          7090    17783
#  2022-07       26174  10019   11163   8250       49096          7169    17951
#
#           Lamphun    Tak  Phitsanulok  ...  AHB_5  AHB_6   AHB_7   AHB_8  \
#  2016-10     3214   2558         7875  ...  43044  38746   54437   66020
#  2016-11     3214   2558         7895  ...  43691  38789   54776   66074
#  2016-12     3214   2558         7895  ...  43747  38787   55087   66392
#  2017-01     3213   2558         7892  ...  44651  40075   55661   66664
#  2017-02     3213   2558         7946  ...  45269  40108   56045   66809
#  ...          ...    ...          ...  ...    ...    ...     ...     ...
#  2022-03    12499  10165        18907  ...  83252  84627   99574  102022
#  2022-04    12650  10318        19057  ...  84282  85627  100517  102461
#  2022-05    12717  10320        19148  ...  84534  85935  100726  103219
#  2022-06    12807  10323        19298  ...  85008  86644  101269  103680
#  2022-07    12910  10547        19530  ...  86057  87629  102001  104396
#
#            AHB_9  AHB_10  AHB_11  AHB_12  AHB_13  Country_Level
#  2016-10   71525   46691   39516   52629   23244       607299.0
#  2016-11   72897   47805   39587   52966   23251       611508.0
#  2016-12   73177   48152   39749   53279   23251       614080.0
#  2017-01   73739   48704   40062   53848   23243       620732.0
#  2017-02   77859   49247   40223   54214   23231       627688.0
#  ...         ...     ...     ...     ...     ...            ...
#  2022-03  144393  101478   77972   92725   39613      1213727.0
#  2022-04  145690  102176   78767   93639   39933      1225461.0
#  2022-05  146809  102429   78995   94019   40963      1231355.0
#  2022-06  148170  102850   79596   94776   41324      1239786.0
#  2022-07  149595  103588   80413   95622   40870      1250291.0
#
#  [70 rows x 91 columns]]

# %%
# split a univariate sequence into samples
def uni_split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)


    # split a multivariate sequence into samples
def multi_split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)


def get_scaler(scaler):
    scalers = {
        "minmax": MinMaxScaler,
        "standard": StandardScaler,
        "maxabs": MaxAbsScaler,
        "robust": RobustScaler,
    }
    return scalers.get(scaler.lower())()


# Add attention layer to the deep learning network
class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)
 
    def build(self,input_shape):
        self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1), 
                               initializer='random_normal', trainable=True)
        self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1), 
                               initializer='zeros', trainable=True)        
        super(attention, self).build(input_shape)
 
    def call(self,x):
        # Alignment scores. Pass them through tanh function
        e = K.tanh(K.dot(x,self.W)+self.b)
        # Remove dimension of size 1
        e = K.squeeze(e, axis=-1)   
        # Compute the weights
        alpha = K.softmax(e)
        # Reshape to tensorFlow format
        alpha = K.expand_dims(alpha, axis=-1)
        # Compute the context vector
        context = x * alpha
        context = K.sum(context, axis=1)
        return context

# %%
# %matplotlib inline
# define scope of configs
AHB_list = [0]
LSTM_hidden_units = [8, 16, 32, 64, 128]
n_layer = [1, 2, 3]
n_batch = [2, 4, 8, 16, 32, 64, 128]
n_steps = [1, 2, 3, 4, 5]
patience_list = [3, 5, 7, 10]
mul_uni = ['uni','mul']
dropouts = [0.2, 0.3, 0.5]


timezone_offset = 7.0  # Bangkok Time (UTC+07:00)
tzinfo = timezone(timedelta(hours=timezone_offset))
count = 1
performance_json = []
for g in AHB_list:
    for h in patience_list:
        for a in n_steps:
            for b in dropouts:
                for c in LSTM_hidden_units:
                    for d in n_layer:
                        for e in n_batch:
                            for f in mul_uni:

                                print('PROGRESS: [ ' + str(count) + ' / ' + str(len(dropouts)*len(AHB_list)*len(n_steps)*len(LSTM_hidden_units)*len(n_layer)*len(n_batch)*len(patience_list)*len(mul_uni)) + ' ]')
                                
                                if f == 'uni':
                                    if g == 13:
                                        raw_seq = list(df_list[g]['Country_Level'])
                                        ahb = 'Country_Level'
                                    else:    
                                        raw_seq = list(df_list[g]['AHB_'+str(g+1)])
                                        ahb = 'AHB_'+str(g+1)
                                    n_features = 1
                                    scaler = get_scaler('minmax')
                                    raw_seq_arr = scaler.fit_transform(np.array(raw_seq).reshape(len(raw_seq),-1))
                                    X, y = uni_split_sequence(raw_seq_arr, a)
                                    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, train_size=0.9, shuffle=False, stratify=None)
                                    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
                                    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))
                                if f == 'mul':
                                    if g == 13:
                                        raw_seq = list(df_list[13].drop(df_list[13].columns[:77], axis=1).values)
                                        ahb = 'Country_Level'
                                        scaler_y = get_scaler('minmax')
                                        scaler_y.fit(np.array(df_list[13]['Country_Level']).reshape(len(df_list[13]['Country_Level']),-1))
                                    else:    
                                        raw_seq = list(df_list[g].drop(['Country_Level'], axis=1).values)
                                        ahb = 'AHB_'+str(g+1)
                                        scaler_y = get_scaler('minmax')
                                        scaler_y.fit(np.array(df_list[g]['AHB_'+str(g+1)]).reshape(len(df_list[13]['AHB_'+str(g+1)]),-1))
                                    n_features = len(raw_seq[0])-1
                                    scaler = get_scaler('minmax')
                                    raw_seq_arr = scaler.fit_transform(np.array(raw_seq))
                                    X, y = multi_split_sequences(raw_seq_arr, a)
                                    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, train_size=0.9, shuffle=False, stratify=None)
                                    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
                                    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

                                callback = EarlyStopping(monitor='loss', patience=h)
                                x=Input(shape=(a,n_features))
                                if d == 1:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    attention_layer = attention()(LSTM_layer)
                                if d == 2:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    LSTM_layer2 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer)
                                    attention_layer = attention()(LSTM_layer2)
                                if d ==3:
                                    LSTM_layer = LSTM(units=c, return_sequences=True, input_shape=(a,n_features), activation='tanh', dropout=b)(x)
                                    LSTM_layer2 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer)
                                    LSTM_layer3 = LSTM(units=c, return_sequences=True, activation='tanh', dropout=b)(LSTM_layer2)
                                    attention_layer = attention()(LSTM_layer3)
                                outputs=Dense(1, trainable=True, activation='tanh')(attention_layer)
                                model=Model(x,outputs)
                                model.compile(loss='mse', optimizer='adam')  
                                history = model.fit(X_train, y_train, epochs=2000, batch_size=e, verbose=0, callbacks=[callback])
                                last_epoch = len(history.history['loss']) 


                                yhat = model.predict(X_test, verbose=0)
                                mae = mean_absolute_error(y_test, yhat)
                                mse = mean_squared_error(y_test, yhat)
                                rmse = mean_squared_error(y_test, yhat, squared = False)
                                mape = mean_absolute_percentage_error(y_test, yhat)

                                yhat = model.predict(X_test, verbose=0)
                                yhat = yhat.reshape(yhat.shape[0],-1)
                                mae = mean_absolute_error(y_test, yhat)
                                mse = mean_squared_error(y_test, yhat)
                                rmse = mean_squared_error(y_test, yhat, squared = False)
                                mape = mean_absolute_percentage_error(y_test, yhat)
                                
                                if f == 'uni':
                                    yhat_inverse = scaler.inverse_transform(yhat)
                                    y_test_inverse = scaler.inverse_transform(y_test)
                                if f == 'mul':
                                    yhat_inverse = scaler_y.inverse_transform(yhat)
                                    y_test_inverse = scaler_y.inverse_transform(y_test.reshape(len(y_test),-1))


                                mae_inverse = mean_absolute_error(y_test_inverse, yhat_inverse)
                                mse_inverse = mean_squared_error(y_test_inverse, yhat_inverse)
                                rmse_inverse = mean_squared_error(y_test_inverse, yhat_inverse, squared = False)
                                mape_inverse = mean_absolute_percentage_error(y_test_inverse, yhat_inverse)

                                performance_json.append({'model': 'LSTM', 'AHB_number': ahb, 'Multi_Uni': f, \
                                                         'n_layer': d, 'LSTM_hidden_units': c, 'dropouts': b,'n_batch': e,\
                                                         'n_steps': a, 'last_epoch': last_epoch, 'patience_list': h, 'MAE_normalize': float(mae), \
                                                         'MSE_normalize': float(mse), 'RMSE_normalize': float(rmse), 'MAPE_normalize': float(mape), \
                                                         'MAE': float(mae_inverse), 'MSE': float(mse_inverse), 'RMSE': float(rmse_inverse), 'MAPE': float(mape_inverse)})
                                

                                json_formatted_str = json.dumps(performance_json[-1], indent=2)
                                print(json_formatted_str)
                                print('Percent CPU Usage: ' + str(psutil.cpu_percent()))
                                print('Percent Ram Usage: ' + str(psutil.virtual_memory()[2]))
                                print(datetime.now(tzinfo))

                                count = count + 1
# Out:
# Streaming output truncated to the last 5000 lines.
#   "MSE": 872038941.879194,
#   "RMSE": 29530.30548232094,
#   "MAPE": 0.21166889573629005
# }
# Percent CPU Usage: 47.1
# Percent Ram Usage: 18.5
# 2022-10-23 22:43:52.039603+07:00
# PROGRESS: [ 10624 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 53,
#   "patience_list": 10,
#   "MAE_normalize": 0.11021358679547022,
#   "MSE_normalize": 0.012496714318572912,
#   "RMSE_normalize": 0.11178870389521882,
#   "MAPE_normalize": 0.11431157159786838,
#   "MAE": 9818.044642857143,
#   "MSE": 99168931.11139788,
#   "RMSE": 9958.359860509052,
#   "MAPE": 0.07034974774476419
# }
# Percent CPU Usage: 52.5
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:00.768393+07:00
# PROGRESS: [ 10625 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 53,
#   "patience_list": 10,
#   "MAE_normalize": 0.2825292013595484,
#   "MSE_normalize": 0.08017807592368219,
#   "RMSE_normalize": 0.28315733422195194,
#   "MAPE_normalize": 0.2938213059649587,
#   "MAE": 25168.265625,
#   "MSE": 636261324.8693498,
#   "RMSE": 25224.220996283508,
#   "MAPE": 0.18063682498130654
# }
# Percent CPU Usage: 52.5
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:11.193801+07:00
# PROGRESS: [ 10626 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 53,
#   "patience_list": 10,
#   "MAE_normalize": 0.1255400441596888,
#   "MSE_normalize": 0.016112001453509914,
#   "RMSE_normalize": 0.12693305894647744,
#   "MAPE_normalize": 0.13027676052830184,
#   "MAE": 11183.357142857143,
#   "MSE": 127858425.76872908,
#   "RMSE": 11307.450011772286,
#   "MAPE": 0.08015871291971251
# }
# Percent CPU Usage: 52.7
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:20.019946+07:00
# PROGRESS: [ 10627 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.3557313515681578,
#   "MSE_normalize": 0.12684073001142696,
#   "RMSE_normalize": 0.3561470623372134,
#   "MAPE_normalize": 0.3701264213291872,
#   "MAE": 31689.258928571428,
#   "MSE": 1006557557.5616281,
#   "RMSE": 31726.291267048975,
#   "MAPE": 0.22750601762729802
# }
# Percent CPU Usage: 62.1
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:26.549153+07:00
# PROGRESS: [ 10628 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.14319810750328182,
#   "MSE_normalize": 0.020759105209661257,
#   "RMSE_normalize": 0.1440802040866866,
#   "MAPE_normalize": 0.14874936773862688,
#   "MAE": 12756.372767857143,
#   "MSE": 164735979.54120746,
#   "RMSE": 12834.951481840804,
#   "MAPE": 0.0914895980928893
# }
# Percent CPU Usage: 59.8
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:30.960109+07:00
# PROGRESS: [ 10629 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.30855674456371973,
#   "MSE_normalize": 0.0954991549762428,
#   "RMSE_normalize": 0.3090293755878926,
#   "MAPE_normalize": 0.3209843376096057,
#   "MAE": 27486.8515625,
#   "MSE": 757843338.0132272,
#   "RMSE": 27528.954539052644,
#   "MAPE": 0.1973136626750271
# }
# Percent CPU Usage: 56.6
# Percent Ram Usage: 18.5
# 2022-10-23 22:44:35.213393+07:00
# PROGRESS: [ 10630 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.09831438799088735,
#   "MSE_normalize": 0.009954576885204637,
#   "RMSE_normalize": 0.09977262593118734,
#   "MAPE_normalize": 0.10196140876281569,
#   "MAE": 8758.04017857143,
#   "MSE": 78995533.93416922,
#   "RMSE": 8887.943177933195,
#   "MAPE": 0.06275122426132604
# }
# Percent CPU Usage: 47.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:44:42.356258+07:00
# PROGRESS: [ 10631 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.3270795861535111,
#   "MSE_normalize": 0.10729230899328952,
#   "RMSE_normalize": 0.3275550472718891,
#   "MAPE_normalize": 0.34026571099466923,
#   "MAE": 29136.901785714286,
#   "MSE": 851429028.4632742,
#   "RMSE": 29179.256818213762,
#   "MAPE": 0.20916322995184752
# }
# Percent CPU Usage: 48.9
# Percent Ram Usage: 18.4
# 2022-10-23 22:44:46.815609+07:00
# PROGRESS: [ 10632 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.10491630914054992,
#   "MSE_normalize": 0.011288805514129729,
#   "RMSE_normalize": 0.10624879064784563,
#   "MAPE_normalize": 0.10884525039972429,
#   "MAE": 9346.152901785714,
#   "MSE": 89583440.68267822,
#   "RMSE": 9464.852913948438,
#   "MAPE": 0.06697902289826252
# }
# Percent CPU Usage: 50.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:44:51.061959+07:00
# PROGRESS: [ 10633 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.3090312571407766,
#   "MSE_normalize": 0.09581102637943555,
#   "RMSE_normalize": 0.3095335626057949,
#   "MAPE_normalize": 0.321463852674893,
#   "MAE": 27529.123883928572,
#   "MSE": 760318324.7944423,
#   "RMSE": 27573.870326714063,
#   "MAPE": 0.1976117861396404
# }
# Percent CPU Usage: 53.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:44:54.710621+07:00
# PROGRESS: [ 10634 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 45,
#   "patience_list": 10,
#   "MAE_normalize": 0.10624208673933967,
#   "MSE_normalize": 0.011555316330288485,
#   "RMSE_normalize": 0.107495657262461,
#   "MAPE_normalize": 0.11023743843523856,
#   "MAE": 9464.255580357143,
#   "MSE": 91698359.26617432,
#   "RMSE": 9575.926026561312,
#   "MAPE": 0.06783173479098223
# }
# Percent CPU Usage: 49.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:44:59.015307+07:00
# PROGRESS: [ 10635 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 51,
#   "patience_list": 10,
#   "MAE_normalize": 0.31649659414475695,
#   "MSE_normalize": 0.10047871730396873,
#   "RMSE_normalize": 0.3169837808216199,
#   "MAPE_normalize": 0.3292426681905814,
#   "MAE": 28194.145089285714,
#   "MSE": 797358925.4852644,
#   "RMSE": 28237.544607937576,
#   "MAPE": 0.20239045940981765
# }
# Percent CPU Usage: 54.8
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:02.566496+07:00
# PROGRESS: [ 10636 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 28,
#   "patience_list": 10,
#   "MAE_normalize": 0.12887152657011972,
#   "MSE_normalize": 0.016888054274569523,
#   "RMSE_normalize": 0.12995404678027353,
#   "MAPE_normalize": 0.13380214452449032,
#   "MAE": 11480.130580357143,
#   "MSE": 134016826.84136963,
#   "RMSE": 11576.56368882276,
#   "MAPE": 0.0823116487729154
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:05.898973+07:00
# PROGRESS: [ 10637 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 56,
#   "patience_list": 10,
#   "MAE_normalize": 0.42215790972212774,
#   "MSE_normalize": 0.17855517098403353,
#   "RMSE_normalize": 0.4225578906895877,
#   "MAPE_normalize": 0.43929567767817407,
#   "MAE": 37606.66852678572,
#   "MSE": 1416942721.700169,
#   "RMSE": 37642.29963352623,
#   "MAPE": 0.2700094091320948
# }
# Percent CPU Usage: 51.5
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:10.790359+07:00
# PROGRESS: [ 10638 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 44,
#   "patience_list": 10,
#   "MAE_normalize": 0.1109119488734557,
#   "MSE_normalize": 0.012578481574690603,
#   "RMSE_normalize": 0.11215382995997329,
#   "MAPE_normalize": 0.1150950329657786,
#   "MAE": 9880.2578125,
#   "MSE": 99817820.77630615,
#   "RMSE": 9990.88688637331,
#   "MAPE": 0.07081785824063733
# }
# Percent CPU Usage: 52.8
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:14.298841+07:00
# PROGRESS: [ 10639 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 73,
#   "patience_list": 10,
#   "MAE_normalize": 0.3357740901420496,
#   "MSE_normalize": 0.11305852208932597,
#   "RMSE_normalize": 0.3362417613701873,
#   "MAPE_normalize": 0.3493210807499071,
#   "MAE": 29911.425223214286,
#   "MSE": 897187382.1656581,
#   "RMSE": 29953.08635459221,
#   "MAPE": 0.21472716252305327
# }
# Percent CPU Usage: 53.7
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:17.892365+07:00
# PROGRESS: [ 10640 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 40,
#   "patience_list": 10,
#   "MAE_normalize": 0.12295075878600105,
#   "MSE_normalize": 0.01540003286270275,
#   "RMSE_normalize": 0.1240968688674406,
#   "MAPE_normalize": 0.12763169732720642,
#   "MAE": 10952.69642857143,
#   "MSE": 122208479.09915598,
#   "RMSE": 11054.794394250668,
#   "MAPE": 0.07852123312898072
# }
# Percent CPU Usage: 51.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:21.463727+07:00
# PROGRESS: [ 10641 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 18,
#   "patience_list": 10,
#   "MAE_normalize": 0.3580611608932398,
#   "MSE_normalize": 0.12847309038526722,
#   "RMSE_normalize": 0.3584314305209118,
#   "MAPE_normalize": 0.37257856533548944,
#   "MAE": 31896.803571428572,
#   "MSE": 1019511354.9225203,
#   "RMSE": 31929.787893478406,
#   "MAPE": 0.22900663300154217
# }
# Percent CPU Usage: 59.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:29.715054+07:00
# PROGRESS: [ 10642 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 33,
#   "patience_list": 10,
#   "MAE_normalize": 0.14151877218158299,
#   "MSE_normalize": 0.020346312449592962,
#   "RMSE_normalize": 0.14264050073381318,
#   "MAPE_normalize": 0.14694720093281574,
#   "MAE": 12606.775669642857,
#   "MSE": 161460269.49856132,
#   "RMSE": 12706.701755316417,
#   "MAPE": 0.09039487709218556
# }
# Percent CPU Usage: 62.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:39.913131+07:00
# PROGRESS: [ 10643 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.31565696054370457,
#   "MSE_normalize": 0.09992340837900952,
#   "RMSE_normalize": 0.3161066408334528,
#   "MAPE_normalize": 0.3283874440127908,
#   "MAE": 28119.34933035714,
#   "MSE": 792952243.3306624,
#   "RMSE": 28159.407723364184,
#   "MAPE": 0.20186042247204433
# }
# Percent CPU Usage: 54.5
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:47.787918+07:00
# PROGRESS: [ 10644 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 18,
#   "patience_list": 10,
#   "MAE_normalize": 0.12744371433442372,
#   "MSE_normalize": 0.0165018026051294,
#   "RMSE_normalize": 0.12845934222597202,
#   "MAPE_normalize": 0.13233167807121443,
#   "MAE": 11352.940848214286,
#   "MSE": 130951750.25525774,
#   "RMSE": 11443.415148252629,
#   "MAPE": 0.08140422260113611
# }
# Percent CPU Usage: 52.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:45:55.832289+07:00
# PROGRESS: [ 10645 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.31812277063826544,
#   "MSE_normalize": 0.10149709130674243,
#   "RMSE_normalize": 0.31858608147052253,
#   "MAPE_normalize": 0.3309474923510431,
#   "MAE": 28339.01004464286,
#   "MSE": 805440438.9425136,
#   "RMSE": 28380.28257333802,
#   "MAPE": 0.20343533568189404
# }
# Percent CPU Usage: 46.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:03.648153+07:00
# PROGRESS: [ 10646 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.09661275201709323,
#   "MSE_normalize": 0.009612946227306577,
#   "RMSE_normalize": 0.09804563339234734,
#   "MAPE_normalize": 0.10019692589608263,
#   "MAE": 8606.45424107143,
#   "MSE": 76284467.50668772,
#   "RMSE": 8734.097978995182,
#   "MAPE": 0.061665210033631776
# }
# Percent CPU Usage: 56.0
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:12.494309+07:00
# PROGRESS: [ 10647 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 30,
#   "patience_list": 10,
#   "MAE_normalize": 0.3252401272110978,
#   "MSE_normalize": 0.10607146738443098,
#   "RMSE_normalize": 0.3256861485916019,
#   "MAPE_normalize": 0.3383659035274104,
#   "MAE": 28973.0390625,
#   "MSE": 841740904.1167253,
#   "RMSE": 29012.771396692275,
#   "MAPE": 0.2079921329585257
# }
# Percent CPU Usage: 53.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:19.091751+07:00
# PROGRESS: [ 10648 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.10746117202398149,
#   "MSE_normalize": 0.011791352159129775,
#   "RMSE_normalize": 0.10858799270236914,
#   "MAPE_normalize": 0.11152867480728831,
#   "MAE": 9572.853794642857,
#   "MSE": 93571442.93454416,
#   "RMSE": 9673.23332368987,
#   "MAPE": 0.06862000027965724
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:25.590069+07:00
# PROGRESS: [ 10649 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.32658135944278294,
#   "MSE_normalize": 0.10696318347385457,
#   "RMSE_normalize": 0.32705226413198024,
#   "MAPE_normalize": 0.33974935876256757,
#   "MAE": 29092.52120535714,
#   "MSE": 848817365.3808333,
#   "RMSE": 29134.470398152655,
#   "MAPE": 0.20884537770575132
# }
# Percent CPU Usage: 49.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:32.020965+07:00
# PROGRESS: [ 10650 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 35,
#   "patience_list": 10,
#   "MAE_normalize": 0.12878490399136255,
#   "MSE_normalize": 0.01684167517576097,
#   "RMSE_normalize": 0.1297754798710487,
#   "MAPE_normalize": 0.13373221927045442,
#   "MAE": 11472.4140625,
#   "MSE": 133648780.2752947,
#   "RMSE": 11560.656567656299,
#   "MAPE": 0.08226387198267567
# }
# Percent CPU Usage: 50.9
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:39.893277+07:00
# PROGRESS: [ 10651 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 43,
#   "patience_list": 10,
#   "MAE_normalize": 0.22441044928871273,
#   "MSE_normalize": 0.0506618827904318,
#   "RMSE_normalize": 0.22508194683366278,
#   "MAPE_normalize": 0.23331502990100297,
#   "MAE": 19990.9296875,
#   "MSE": 402032502.9186576,
#   "RMSE": 20050.748188500536,
#   "MAPE": 0.14345379809980038
# }
# Percent CPU Usage: 49.5
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:46.436223+07:00
# PROGRESS: [ 10652 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 35,
#   "patience_list": 10,
#   "MAE_normalize": 0.07504724658060467,
#   "MSE_normalize": 0.005962400468050216,
#   "RMSE_normalize": 0.07721658156154167,
#   "MAPE_normalize": 0.07769038830084744,
#   "MAE": 6685.359375,
#   "MSE": 47315243.07920619,
#   "RMSE": 6878.607641027811,
#   "MAPE": 0.047847320943998885
# }
# Percent CPU Usage: 48.7
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:52.855875+07:00
# PROGRESS: [ 10653 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 66,
#   "patience_list": 10,
#   "MAE_normalize": 0.34875495146527,
#   "MSE_normalize": 0.1219362672761308,
#   "RMSE_normalize": 0.349193738884492,
#   "MAPE_normalize": 0.3628504393532755,
#   "MAE": 31067.78683035714,
#   "MSE": 967637668.4367415,
#   "RMSE": 31106.874938455992,
#   "MAPE": 0.22303777195481933
# }
# Percent CPU Usage: 51.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:46:59.366401+07:00
# PROGRESS: [ 10654 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 49,
#   "patience_list": 10,
#   "MAE_normalize": 0.16844133873170156,
#   "MSE_normalize": 0.028627262186488985,
#   "RMSE_normalize": 0.16919592839808228,
#   "MAPE_normalize": 0.17504634219277287,
#   "MAE": 15005.090401785714,
#   "MSE": 227174548.65031216,
#   "RMSE": 15072.310660622417,
#   "MAPE": 0.10764594461775331
# }
# Percent CPU Usage: 50.3
# Percent Ram Usage: 18.4
# 2022-10-23 22:47:07.221172+07:00
# PROGRESS: [ 10655 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 13,
#   "patience_list": 10,
#   "MAE_normalize": 0.35689531107133166,
#   "MSE_normalize": 0.12764499897319245,
#   "RMSE_normalize": 0.35727440290789436,
#   "MAPE_normalize": 0.3713594388931173,
#   "MAE": 31792.94754464286,
#   "MSE": 1012939966.537153,
#   "RMSE": 31826.71780968237,
#   "MAPE": 0.22825872029508337
# }
# Percent CPU Usage: 50.3
# Percent Ram Usage: 18.4
# 2022-10-23 22:47:19.817248+07:00
# PROGRESS: [ 10656 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 31,
#   "patience_list": 10,
#   "MAE_normalize": 0.16825872713000825,
#   "MSE_normalize": 0.028686760585831823,
#   "RMSE_normalize": 0.16937166405816476,
#   "MAPE_normalize": 0.17476259264659202,
#   "MAE": 14988.8203125,
#   "MSE": 227646625.74877056,
#   "RMSE": 15087.962942318309,
#   "MAPE": 0.10749374024196182
# }
# Percent CPU Usage: 46.3
# Percent Ram Usage: 18.4
# 2022-10-23 22:47:36.559614+07:00
# PROGRESS: [ 10657 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 33,
#   "patience_list": 10,
#   "MAE_normalize": 0.37070936869396875,
#   "MSE_normalize": 0.13768482312592958,
#   "RMSE_normalize": 0.3710590561163136,
#   "MAPE_normalize": 0.3857601249684315,
#   "MAE": 33023.53013392857,
#   "MSE": 1092611933.9943585,
#   "RMSE": 33054.68096948386,
#   "MAPE": 0.2371038497979585
# }
# Percent CPU Usage: 55.7
# Percent Ram Usage: 18.4
# 2022-10-23 22:47:50.643048+07:00
# PROGRESS: [ 10658 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.13414556692852686,
#   "MSE_normalize": 0.018302612787686322,
#   "RMSE_normalize": 0.13528714938118225,
#   "MAPE_normalize": 0.139274900582069,
#   "MAE": 11949.95200892857,
#   "MSE": 145242183.48958042,
#   "RMSE": 12051.646505336124,
#   "MAPE": 0.08567906959785855
# }
# Percent CPU Usage: 58.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:48:01.383605+07:00
# PROGRESS: [ 10659 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 32,
#   "patience_list": 10,
#   "MAE_normalize": 0.32278683409193976,
#   "MSE_normalize": 0.104473362650626,
#   "RMSE_normalize": 0.323223394343024,
#   "MAPE_normalize": 0.3358168229772823,
#   "MAE": 28754.49441964286,
#   "MSE": 829058973.1439993,
#   "RMSE": 28793.384190539313,
#   "MAPE": 0.2064244575942262
# }
# Percent CPU Usage: 56.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:48:11.417862+07:00
# PROGRESS: [ 10660 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 39,
#   "patience_list": 10,
#   "MAE_normalize": 0.14196087686178055,
#   "MSE_normalize": 0.020453609700977832,
#   "RMSE_normalize": 0.14301611692735133,
#   "MAPE_normalize": 0.14742204218916138,
#   "MAE": 12646.15736607143,
#   "MSE": 162311677.5371704,
#   "RMSE": 12740.160027926275,
#   "MAPE": 0.09068320602018483
# }
# Percent CPU Usage: 48.8
# Percent Ram Usage: 18.4
# 2022-10-23 22:48:25.966275+07:00
# PROGRESS: [ 10661 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 44,
#   "patience_list": 10,
#   "MAE_normalize": 0.3124678991744898,
#   "MSE_normalize": 0.09790157361795206,
#   "RMSE_normalize": 0.3128922715855284,
#   "MAPE_normalize": 0.32508059517539617,
#   "MAE": 27835.26339285714,
#   "MSE": 776907880.7997524,
#   "RMSE": 27873.06730160411,
#   "MAPE": 0.19982514293501033
# }
# Percent CPU Usage: 52.4
# Percent Ram Usage: 18.4
# 2022-10-23 22:48:36.208211+07:00
# PROGRESS: [ 10662 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 62,
#   "patience_list": 10,
#   "MAE_normalize": 0.1186693826966325,
#   "MSE_normalize": 0.01439015723302973,
#   "RMSE_normalize": 0.11995898146045476,
#   "MAPE_normalize": 0.12315203463544731,
#   "MAE": 10571.30357142857,
#   "MSE": 114194523.12672642,
#   "RMSE": 10686.183749436766,
#   "MAPE": 0.07577365625660051
# }
# Percent CPU Usage: 56.7
# Percent Ram Usage: 18.4
# 2022-10-23 22:48:46.332679+07:00
# PROGRESS: [ 10663 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 37,
#   "patience_list": 10,
#   "MAE_normalize": 0.3119732828022451,
#   "MSE_normalize": 0.09762868111783585,
#   "RMSE_normalize": 0.31245588667496066,
#   "MAPE_normalize": 0.3245360859892857,
#   "MAE": 27791.20089285714,
#   "MSE": 774742257.4299142,
#   "RMSE": 27834.192235987633,
#   "MAPE": 0.19949752390336295
# }
# Percent CPU Usage: 48.2
# Percent Ram Usage: 18.3
# 2022-10-23 22:48:57.962370+07:00
# PROGRESS: [ 10664 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 63,
#   "patience_list": 10,
#   "MAE_normalize": 0.11575490289599948,
#   "MSE_normalize": 0.01363990533231434,
#   "RMSE_normalize": 0.11679000527576981,
#   "MAPE_normalize": 0.12017144543241796,
#   "MAE": 10311.67857142857,
#   "MSE": 108240880.40112305,
#   "RMSE": 10403.887754158204,
#   "MAPE": 0.0739292969133707
# }
# Percent CPU Usage: 50.7
# Percent Ram Usage: 18.3
# 2022-10-23 22:49:07.864099+07:00
# PROGRESS: [ 10665 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 44,
#   "patience_list": 10,
#   "MAE_normalize": 0.2971697455015903,
#   "MSE_normalize": 0.08864948079320786,
#   "RMSE_normalize": 0.29774062670923473,
#   "MAPE_normalize": 0.3090849411393898,
#   "MAE": 26472.47433035714,
#   "MSE": 703487019.2912337,
#   "RMSE": 26523.329717274068,
#   "MAPE": 0.1900116767747964
# }
# Percent CPU Usage: 52.4
# Percent Ram Usage: 18.3
# 2022-10-23 22:49:17.908417+07:00
# PROGRESS: [ 10666 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 35,
#   "patience_list": 10,
#   "MAE_normalize": 0.06784852115270464,
#   "MSE_normalize": 0.004946785347589845,
#   "RMSE_normalize": 0.07033338714714261,
#   "MAPE_normalize": 0.07018135576878747,
#   "MAE": 6044.080357142857,
#   "MSE": 39255699.553152904,
#   "RMSE": 6265.436900420665,
#   "MAPE": 0.043236215837028524
# }
# Percent CPU Usage: 52.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:49:26.594935+07:00
# PROGRESS: [ 10667 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 45,
#   "patience_list": 10,
#   "MAE_normalize": 0.30901632191978573,
#   "MSE_normalize": 0.09583613326700978,
#   "RMSE_normalize": 0.30957411595126905,
#   "MAPE_normalize": 0.32142239785670107,
#   "MAE": 27527.792410714286,
#   "MSE": 760517505.1246164,
#   "RMSE": 27577.4818488675,
#   "MAPE": 0.19759244299673842
# }
# Percent CPU Usage: 52.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:49:35.113587+07:00
# PROGRESS: [ 10668 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 64,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 37,
#   "patience_list": 10,
#   "MAE_normalize": 0.07685202413470797,
#   "MSE_normalize": 0.006249966344829684,
#   "RMSE_normalize": 0.07905672864993646,
#   "MAPE_normalize": 0.0795607062042003,
#   "MAE": 6846.129464285715,
#   "MSE": 49597227.43561663,
#   "RMSE": 7042.529903068686,
#   "MAPE": 0.048998699907014595
# }
# Percent CPU Usage: 52.1
# Percent Ram Usage: 18.5
# 2022-10-23 22:49:45.517647+07:00
# PROGRESS: [ 10669 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.364489027965209,
#   "MSE_normalize": 0.1331580186394433,
#   "RMSE_normalize": 0.36490823317574417,
#   "MAPE_normalize": 0.3792421835904056,
#   "MAE": 32469.409598214286,
#   "MSE": 1056689004.3757237,
#   "RMSE": 32506.7532118439,
#   "MAPE": 0.23310833451833296
# }
# Percent CPU Usage: 43.2
# Percent Ram Usage: 18.5
# 2022-10-23 22:49:53.665548+07:00
# PROGRESS: [ 10670 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 16,
#   "patience_list": 10,
#   "MAE_normalize": 0.1358264860307869,
#   "MSE_normalize": 0.01870929814826602,
#   "RMSE_normalize": 0.13678193648382822,
#   "MAPE_normalize": 0.14106381982827818,
#   "MAE": 12099.693080357143,
#   "MSE": 148469514.7738473,
#   "RMSE": 12184.806718772657,
#   "MAPE": 0.08676921165720927
# }
# Percent CPU Usage: 53.0
# Percent Ram Usage: 18.5
# 2022-10-23 22:49:58.857459+07:00
# PROGRESS: [ 10671 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 27,
#   "patience_list": 10,
#   "MAE_normalize": 0.3276671431968592,
#   "MSE_normalize": 0.10765086150438415,
#   "RMSE_normalize": 0.328101907194067,
#   "MAPE_normalize": 0.3408985418478611,
#   "MAE": 29189.241071428572,
#   "MSE": 854274266.8334438,
#   "RMSE": 29227.97062461648,
#   "MAPE": 0.20954710510365504
# }
# Percent CPU Usage: 52.7
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:04.573486+07:00
# PROGRESS: [ 10672 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 31,
#   "patience_list": 10,
#   "MAE_normalize": 0.12343720932191152,
#   "MSE_normalize": 0.015492647420073027,
#   "RMSE_normalize": 0.12446946380567817,
#   "MAPE_normalize": 0.12816087814452842,
#   "MAE": 10996.033482142857,
#   "MSE": 122943498.08267649,
#   "RMSE": 11087.988910649057,
#   "MAPE": 0.07884107434482603
# }
# Percent CPU Usage: 56.4
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:10.159020+07:00
# PROGRESS: [ 10673 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 22,
#   "patience_list": 10,
#   "MAE_normalize": 0.30425021531425595,
#   "MSE_normalize": 0.09285525326188927,
#   "RMSE_normalize": 0.304721599598534,
#   "MAPE_normalize": 0.3165017949112895,
#   "MAE": 27103.217633928572,
#   "MSE": 736862403.0480347,
#   "RMSE": 27145.20957826693,
#   "MAPE": 0.19455878725852832
# }
# Percent CPU Usage: 52.1
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:14.602849+07:00
# PROGRESS: [ 10674 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.13435318693617807,
#   "MSE_normalize": 0.018295705118712004,
#   "RMSE_normalize": 0.1352616173151571,
#   "MAPE_normalize": 0.1395423243726706,
#   "MAE": 11968.450892857143,
#   "MSE": 145187451.87615094,
#   "RMSE": 12049.375580342366,
#   "MAPE": 0.08583129678982225
# }
# Percent CPU Usage: 44.9
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:20.108804+07:00
# PROGRESS: [ 10675 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.3190722555996389,
#   "MSE_normalize": 0.1020955483009455,
#   "RMSE_normalize": 0.3195239401061296,
#   "MAPE_normalize": 0.33194189485513875,
#   "MAE": 28423.59151785714,
#   "MSE": 810189541.1018764,
#   "RMSE": 28463.828644472203,
#   "MAPE": 0.20404502087419774
# }
# Percent CPU Usage: 49.9
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:26.033943+07:00
# PROGRESS: [ 10676 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 40,
#   "patience_list": 10,
#   "MAE_normalize": 0.09916847997577243,
#   "MSE_normalize": 0.010098015180748935,
#   "RMSE_normalize": 0.10048888088116484,
#   "MAPE_normalize": 0.10287192077842926,
#   "MAE": 8834.125,
#   "MSE": 80133811.22384207,
#   "RMSE": 8951.749059476704,
#   "MAPE": 0.06330571070990201
# }
# Percent CPU Usage: 51.5
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:30.299583+07:00
# PROGRESS: [ 10677 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.26193902375541805,
#   "MSE_normalize": 0.06890650084348994,
#   "RMSE_normalize": 0.26250047779668884,
#   "MAPE_normalize": 0.2724171690354881,
#   "MAE": 23334.047991071428,
#   "MSE": 546814433.4121181,
#   "RMSE": 23384.063663360954,
#   "MAPE": 0.1674757250660885
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:33.926946+07:00
# PROGRESS: [ 10678 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 19,
#   "patience_list": 10,
#   "MAE_normalize": 0.09214604805721949,
#   "MSE_normalize": 0.008788503813749486,
#   "RMSE_normalize": 0.09374702029264442,
#   "MAPE_normalize": 0.09552856521917454,
#   "MAE": 8208.552455357143,
#   "MSE": 69742041.45191301,
#   "RMSE": 8351.170064841992,
#   "MAPE": 0.05880066882933892
# }
# Percent CPU Usage: 51.3
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:37.473603+07:00
# PROGRESS: [ 10679 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 51,
#   "patience_list": 10,
#   "MAE_normalize": 0.2898379654766531,
#   "MSE_normalize": 0.08431265967113824,
#   "RMSE_normalize": 0.2903664231124843,
#   "MAPE_normalize": 0.3014719699604265,
#   "MAE": 25819.344866071428,
#   "MSE": 669071732.9804077,
#   "RMSE": 25866.42095421026,
#   "MAPE": 0.18532852738203848
# }
# Percent CPU Usage: 46.2
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:41.672339+07:00
# PROGRESS: [ 10680 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 30,
#   "patience_list": 10,
#   "MAE_normalize": 0.08446168952853732,
#   "MSE_normalize": 0.007439532296159895,
#   "RMSE_normalize": 0.08625272341300241,
#   "MAPE_normalize": 0.08751681794968746,
#   "MAE": 7524.015625,
#   "MSE": 59037169.08450753,
#   "RMSE": 7683.564868243616,
#   "MAPE": 0.05387998203282524
# }
# Percent CPU Usage: 53.1
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:45.085500+07:00
# PROGRESS: [ 10681 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 67,
#   "patience_list": 10,
#   "MAE_normalize": 0.288192766586512,
#   "MSE_normalize": 0.08335741080537393,
#   "RMSE_normalize": 0.28871683498780243,
#   "MAPE_normalize": 0.29976138925140516,
#   "MAE": 25672.785714285714,
#   "MSE": 661491177.5677316,
#   "RMSE": 25719.47078708525,
#   "MAPE": 0.18427678839672076
# }
# Percent CPU Usage: 48.6
# Percent Ram Usage: 18.5
# 2022-10-23 22:50:49.472094+07:00
# PROGRESS: [ 10682 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 31,
#   "patience_list": 10,
#   "MAE_normalize": 0.08501388398763506,
#   "MSE_normalize": 0.007516383109578411,
#   "RMSE_normalize": 0.08669707670722475,
#   "MAPE_normalize": 0.08810536918058891,
#   "MAE": 7573.209821428572,
#   "MSE": 59647078.53473772,
#   "RMSE": 7723.152111329785,
#   "MAPE": 0.0542384449091351
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:50:54.350788+07:00
# PROGRESS: [ 10683 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.4434446144326794,
#   "MSE_normalize": 0.1968321547704515,
#   "RMSE_normalize": 0.443657700001309,
#   "MAPE_normalize": 0.46159873385920713,
#   "MAE": 39502.93415178572,
#   "MSE": 1561981866.4318063,
#   "RMSE": 39521.916279854224,
#   "MAPE": 0.28368175275273677
# }
# Percent CPU Usage: 64.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:05.198407+07:00
# PROGRESS: [ 10684 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.15243126718160477,
#   "MSE_normalize": 0.023524995860103575,
#   "RMSE_normalize": 0.15337860300610243,
#   "MAPE_normalize": 0.15833811711354162,
#   "MAE": 13578.880580357143,
#   "MSE": 186684983.6723371,
#   "RMSE": 13663.271338604716,
#   "MAPE": 0.09738780435658947
# }
# Percent CPU Usage: 63.9
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:14.060895+07:00
# PROGRESS: [ 10685 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 19,
#   "patience_list": 10,
#   "MAE_normalize": 0.33418816381366306,
#   "MSE_normalize": 0.1119721048758311,
#   "RMSE_normalize": 0.3346223317052093,
#   "MAPE_normalize": 0.3476877185902816,
#   "MAE": 29770.1484375,
#   "MSE": 888566048.3095093,
#   "RMSE": 29808.825007193915,
#   "MAPE": 0.2137192170810411
# }
# Percent CPU Usage: 59.0
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:21.822416+07:00
# PROGRESS: [ 10686 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.1452533097149343,
#   "MSE_normalize": 0.021367105412740544,
#   "RMSE_normalize": 0.14617491375999012,
#   "MAPE_normalize": 0.15087761747963135,
#   "MAE": 12939.455357142857,
#   "MSE": 169560854.29160854,
#   "RMSE": 13021.553451551337,
#   "MAPE": 0.09280017889997036
# }
# Percent CPU Usage: 50.1
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:33.409212+07:00
# PROGRESS: [ 10687 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.29902006951925125,
#   "MSE_normalize": 0.08972432172441912,
#   "RMSE_normalize": 0.29954018382250336,
#   "MAPE_normalize": 0.31103398140341426,
#   "MAE": 26637.30245535714,
#   "MSE": 712016397.981489,
#   "RMSE": 26683.63539665255,
#   "MAPE": 0.1912040255488827
# }
# Percent CPU Usage: 50.8
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:41.367508+07:00
# PROGRESS: [ 10688 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 22,
#   "patience_list": 10,
#   "MAE_normalize": 0.1212756979688275,
#   "MSE_normalize": 0.014967934094245402,
#   "RMSE_normalize": 0.12234350859054763,
#   "MAPE_normalize": 0.12590574906476434,
#   "MAE": 10803.481026785714,
#   "MSE": 118779562.55171421,
#   "RMSE": 10898.603697341885,
#   "MAPE": 0.07745635870645051
# }
# Percent CPU Usage: 51.2
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:49.311276+07:00
# PROGRESS: [ 10689 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 16,
#   "patience_list": 10,
#   "MAE_normalize": 0.33036292504086207,
#   "MSE_normalize": 0.1094443294994774,
#   "RMSE_normalize": 0.3308237136292944,
#   "MAPE_normalize": 0.34369134278199304,
#   "MAE": 29429.38839285714,
#   "MSE": 868506623.7751988,
#   "RMSE": 29470.436436795415,
#   "MAPE": 0.21126663329052092
# }
# Percent CPU Usage: 52.7
# Percent Ram Usage: 18.4
# 2022-10-23 22:51:55.973247+07:00
# PROGRESS: [ 10690 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.09552467774166773,
#   "MSE_normalize": 0.009390330976148673,
#   "RMSE_normalize": 0.09690372013575471,
#   "MAPE_normalize": 0.09907468643701466,
#   "MAE": 8509.526785714286,
#   "MSE": 74517885.4313616,
#   "RMSE": 8632.374263860529,
#   "MAPE": 0.0609730643839742
# }
# Percent CPU Usage: 54.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:04.251475+07:00
# PROGRESS: [ 10691 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 32,
#   "patience_list": 10,
#   "MAE_normalize": 0.3032159470031641,
#   "MSE_normalize": 0.09225441071324476,
#   "RMSE_normalize": 0.3037341118696495,
#   "MAPE_normalize": 0.31540268892450235,
#   "MAE": 27011.08035714286,
#   "MSE": 732094208.0456369,
#   "RMSE": 27057.239475704777,
#   "MAPE": 0.1938886295979634
# }
# Percent CPU Usage: 46.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:12.320692+07:00
# PROGRESS: [ 10692 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 32,
#   "n_steps": 2,
#   "last_epoch": 50,
#   "patience_list": 10,
#   "MAE_normalize": 0.1259679884792776,
#   "MSE_normalize": 0.016101132290694955,
#   "RMSE_normalize": 0.12689023717644693,
#   "MAPE_normalize": 0.1308175749632548,
#   "MAE": 11221.479910714286,
#   "MSE": 127772180.59779575,
#   "RMSE": 11303.635724747846,
#   "MAPE": 0.08046848648248765
# }
# Percent CPU Usage: 49.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:20.157915+07:00
# PROGRESS: [ 10693 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.1878749818684072,
#   "MSE_normalize": 0.03560669763318518,
#   "RMSE_normalize": 0.188697370498863,
#   "MAPE_normalize": 0.19524719599411797,
#   "MAE": 16736.276785714286,
#   "MSE": 282560532.40337265,
#   "RMSE": 16809.53694791658,
#   "MAPE": 0.12006737015259276
# }
# Percent CPU Usage: 51.9
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:26.626760+07:00
# PROGRESS: [ 10694 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 64,
#   "n_steps": 2,
#   "last_epoch": 27,
#   "patience_list": 10,
#   "MAE_normalize": 0.05889711263023497,
#   "MSE_normalize": 0.0037977810736398434,
#   "RMSE_normalize": 0.06162613953218101,
#   "MAPE_normalize": 0.060866708400895454,
#   "MAE": 5246.671875,
#   "MSE": 30137684.098737445,
#   "RMSE": 5489.779968153318,
#   "MAPE": 0.037511013552722294
# }
# Percent CPU Usage: 50.9
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:34.573228+07:00
# PROGRESS: [ 10695 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 34,
#   "patience_list": 10,
#   "MAE_normalize": 0.2015566831198459,
#   "MSE_normalize": 0.0409355233520396,
#   "RMSE_normalize": 0.20232529093526494,
#   "MAPE_normalize": 0.20949986099913254,
#   "MAE": 17955.0703125,
#   "MSE": 324847979.5408674,
#   "RMSE": 18023.539595231214,
#   "MAPE": 0.12882397122166775
# }
# Percent CPU Usage: 54.0
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:40.912300+07:00
# PROGRESS: [ 10696 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 128,
#   "n_steps": 2,
#   "last_epoch": 26,
#   "patience_list": 10,
#   "MAE_normalize": 0.05209851318271213,
#   "MSE_normalize": 0.003051167714545195,
#   "RMSE_normalize": 0.05523737606499059,
#   "MAPE_normalize": 0.05377811067204747,
#   "MAE": 4641.037946428572,
#   "MSE": 24212848.668701172,
#   "RMSE": 4920.655308869051,
#   "MAPE": 0.03315737947873725
# }
# Percent CPU Usage: 50.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:52:47.532254+07:00
# PROGRESS: [ 10697 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 26,
#   "patience_list": 10,
#   "MAE_normalize": 0.46229461740269373,
#   "MSE_normalize": 0.21390700978749258,
#   "RMSE_normalize": 0.4625008213911545,
#   "MAPE_normalize": 0.4812345565519331,
#   "MAE": 41182.127232142855,
#   "MSE": 1697480897.2413156,
#   "RMSE": 41200.4963227546,
#   "MAPE": 0.2957458508450161
# }
# Percent CPU Usage: 58.6
# Percent Ram Usage: 18.4
# 2022-10-23 22:53:05.119119+07:00
# PROGRESS: [ 10698 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 2,
#   "n_steps": 2,
#   "last_epoch": 15,
#   "patience_list": 10,
#   "MAE_normalize": 0.0725668333480738,
#   "MSE_normalize": 0.005612968314912815,
#   "RMSE_normalize": 0.07491974582787114,
#   "MAPE_normalize": 0.07509391013784383,
#   "MAE": 6464.397321428572,
#   "MSE": 44542272.93624442,
#   "RMSE": 6673.999770470809,
#   "MAPE": 0.046255045752399214
# }
# Percent CPU Usage: 56.4
# Percent Ram Usage: 18.3
# 2022-10-23 22:53:18.194758+07:00
# PROGRESS: [ 10699 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 44,
#   "patience_list": 10,
#   "MAE_normalize": 0.47670337611110264,
#   "MSE_normalize": 0.22746358209330836,
#   "RMSE_normalize": 0.47693142284117573,
#   "MAPE_normalize": 0.4962193425850843,
#   "MAE": 42465.69084821428,
#   "MSE": 1805060680.507734,
#   "RMSE": 42486.005701968905,
#   "MAPE": 0.30495825822643224
# }
# Percent CPU Usage: 65.8
# Percent Ram Usage: 18.3
# 2022-10-23 22:53:32.818820+07:00
# PROGRESS: [ 10700 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 4,
#   "n_steps": 2,
#   "last_epoch": 23,
#   "patience_list": 10,
#   "MAE_normalize": 0.14462216464635697,
#   "MSE_normalize": 0.021225142858885264,
#   "RMSE_normalize": 0.14568851313293463,
#   "MAPE_normalize": 0.15018743429091505,
#   "MAE": 12883.228794642857,
#   "MSE": 168434227.92903355,
#   "RMSE": 12978.221292959739,
#   "MAPE": 0.09238386073464598
# }
# Percent CPU Usage: 60.0
# Percent Ram Usage: 18.3
# 2022-10-23 22:53:45.535833+07:00
# PROGRESS: [ 10701 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 18,
#   "patience_list": 10,
#   "MAE_normalize": 0.33121877110529335,
#   "MSE_normalize": 0.11001236739701341,
#   "RMSE_normalize": 0.33168112306402575,
#   "MAPE_normalize": 0.34458150037465546,
#   "MAE": 29505.629464285714,
#   "MSE": 873014380.8324498,
#   "RMSE": 29546.816763104107,
#   "MAPE": 0.21181386945598055
# }
# Percent CPU Usage: 54.4
# Percent Ram Usage: 18.3
# 2022-10-23 22:53:55.613917+07:00
# PROGRESS: [ 10702 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 8,
#   "n_steps": 2,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.147978629917898,
#   "MSE_normalize": 0.02217638340936919,
#   "RMSE_normalize": 0.148917371079969,
#   "MAPE_normalize": 0.1537087468532958,
#   "MAE": 13182.232142857143,
#   "MSE": 175982962.74443707,
#   "RMSE": 13265.857030152145,
#   "MAPE": 0.09454144262820534
# }
# Percent CPU Usage: 48.4
# Percent Ram Usage: 18.3
# 2022-10-23 22:54:08.117213+07:00
# PROGRESS: [ 10703 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 25,
#   "patience_list": 10,
#   "MAE_normalize": 0.31728564043229357,
#   "MSE_normalize": 0.10096510104797851,
#   "RMSE_normalize": 0.3177500606577102,
#   "MAPE_normalize": 0.33007545254413767,
#   "MAE": 28264.4375,
#   "MSE": 801218814.5867397,
#   "RMSE": 28305.808848834185,
#   "MAPE": 0.20289956808783843
# }
# Percent CPU Usage: 52.3
# Percent Ram Usage: 18.6
# 2022-10-23 22:54:19.755502+07:00
# PROGRESS: [ 10704 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 128,
#   "dropouts": 0.5,
#   "n_batch": 16,
#   "n_steps": 2,
#   "last_epoch": 46,
#   "patience_list": 10,
#   "MAE_normalize": 0.11537226662138923,
#   "MSE_normalize": 0.013605185168742952,
# ...
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 91,
#   "patience_list": 10,
#   "MAE_normalize": 0.2724212753995526,
#   "MSE_normalize": 0.07451087119791112,
#   "RMSE_normalize": 0.27296679504641425,
#   "MAPE_normalize": 0.2833344370956782,
#   "MAE": 24267.831473214286,
#   "MSE": 591288646.7544382,
#   "RMSE": 24316.427508053854,
#   "MAPE": 0.17418372711882377
# }
# Percent CPU Usage: 54.5
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:09.163398+07:00
# PROGRESS: [ 10806 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 47,
#   "patience_list": 10,
#   "MAE_normalize": 0.14207289953416127,
#   "MSE_normalize": 0.0204829059532542,
#   "RMSE_normalize": 0.14311850318269193,
#   "MAPE_normalize": 0.1475405835055665,
#   "MAE": 12656.136160714286,
#   "MSE": 162544156.94921875,
#   "RMSE": 12749.280644382206,
#   "MAPE": 0.09075559642398777
# }
# Percent CPU Usage: 51.0
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:14.129177+07:00
# PROGRESS: [ 10807 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 1,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 98,
#   "patience_list": 10,
#   "MAE_normalize": 0.2726289975865948,
#   "MSE_normalize": 0.07462430179675437,
#   "RMSE_normalize": 0.27317448965222646,
#   "MAPE_normalize": 0.2835506843046069,
#   "MAE": 24286.337053571428,
#   "MSE": 592188855.9386336,
#   "RMSE": 24334.930777354464,
#   "MAPE": 0.17431662774053522
# }
# Percent CPU Usage: 54.4
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:17.826433+07:00
# PROGRESS: [ 10808 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 1,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 52,
#   "patience_list": 10,
#   "MAE_normalize": 0.13782027842842223,
#   "MSE_normalize": 0.01927787010143887,
#   "RMSE_normalize": 0.13884476980224666,
#   "MAPE_normalize": 0.1431221403038319,
#   "MAE": 12277.30357142857,
#   "MSE": 152981456.51960102,
#   "RMSE": 12368.567278371453,
#   "MAPE": 0.08803821546040666
# }
# Percent CPU Usage: 51.4
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:21.461669+07:00
# PROGRESS: [ 10809 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 70,
#   "patience_list": 10,
#   "MAE_normalize": 0.19002414654507346,
#   "MSE_normalize": 0.03619565047734047,
#   "RMSE_normalize": 0.19025154526925786,
#   "MAPE_normalize": 0.1977132186469792,
#   "MAE": 16927.731026785714,
#   "MSE": 287234302.9422869,
#   "RMSE": 16947.98816798876,
#   "MAPE": 0.12152870058502803
# }
# Percent CPU Usage: 61.7
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:36.349588+07:00
# PROGRESS: [ 10810 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.08902478271396212,
#   "MSE_normalize": 0.008203534879819058,
#   "RMSE_normalize": 0.09057336738699218,
#   "MAPE_normalize": 0.09229263466185422,
#   "MAE": 7930.503348214285,
#   "MSE": 65099953.331621446,
#   "RMSE": 8068.454209551012,
#   "MAPE": 0.05680886258975963
# }
# Percent CPU Usage: 65.2
# Percent Ram Usage: 18.5
# 2022-10-23 23:08:48.897068+07:00
# PROGRESS: [ 10811 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 45,
#   "patience_list": 10,
#   "MAE_normalize": 0.15259610808420573,
#   "MSE_normalize": 0.023472547982198996,
#   "RMSE_normalize": 0.1532075323938056,
#   "MAPE_normalize": 0.15860161535589734,
#   "MAE": 13593.564732142857,
#   "MSE": 186268769.01836285,
#   "RMSE": 13648.031690260792,
#   "MAPE": 0.09752795055046368
# }
# Percent CPU Usage: 48.8
# Percent Ram Usage: 18.4
# 2022-10-23 23:08:59.877444+07:00
# PROGRESS: [ 10812 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 21,
#   "patience_list": 10,
#   "MAE_normalize": 0.0744390918750121,
#   "MSE_normalize": 0.005801224876510897,
#   "RMSE_normalize": 0.07616577234237763,
#   "MAPE_normalize": 0.07711289625077962,
#   "MAE": 6631.180803571428,
#   "MSE": 46036196.76419503,
#   "RMSE": 6784.997919247657,
#   "MAPE": 0.04747921019405186
# }
# Percent CPU Usage: 56.9
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:07.817957+07:00
# PROGRESS: [ 10813 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 30,
#   "patience_list": 10,
#   "MAE_normalize": 0.13605071018948267,
#   "MSE_normalize": 0.01868033101772243,
#   "RMSE_normalize": 0.1366760074692059,
#   "MAPE_normalize": 0.14138173462504908,
#   "MAE": 12119.666294642857,
#   "MSE": 148239613.73046002,
#   "RMSE": 12175.369141445364,
#   "MAPE": 0.08694455198453159
# }
# Percent CPU Usage: 51.7
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:15.713012+07:00
# PROGRESS: [ 10814 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 36,
#   "patience_list": 10,
#   "MAE_normalize": 0.10038326521104116,
#   "MSE_normalize": 0.0103269743292593,
#   "RMSE_normalize": 0.10162172173929794,
#   "MAPE_normalize": 0.10414928720348274,
#   "MAE": 8942.341517857143,
#   "MSE": 81950763.5038365,
#   "RMSE": 9052.666099212789,
#   "MAPE": 0.06408768074516547
# }
# Percent CPU Usage: 55.6
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:23.777391+07:00
# PROGRESS: [ 10815 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 36,
#   "patience_list": 10,
#   "MAE_normalize": 0.1309368445414855,
#   "MSE_normalize": 0.017322821145204066,
#   "RMSE_normalize": 0.13161618876568362,
#   "MAPE_normalize": 0.13604609988082741,
#   "MAE": 11664.113839285714,
#   "MSE": 137466974.94520786,
#   "RMSE": 11724.631121924811,
#   "MAPE": 0.08366841354683233
# }
# Percent CPU Usage: 47.8
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:33.345172+07:00
# PROGRESS: [ 10816 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.09078728354502118,
#   "MSE_normalize": 0.008496905248262797,
#   "RMSE_normalize": 0.092178659397188,
#   "MAPE_normalize": 0.09414863725698971,
#   "MAE": 8087.5078125,
#   "MSE": 67427979.40646799,
#   "RMSE": 8211.454159067564,
#   "MAPE": 0.05794441325617423
# }
# Percent CPU Usage: 55.1
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:40.436347+07:00
# PROGRESS: [ 10817 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 67,
#   "patience_list": 10,
#   "MAE_normalize": 0.1466663570286245,
#   "MSE_normalize": 0.02168482210380545,
#   "RMSE_normalize": 0.14725767247856883,
#   "MAPE_normalize": 0.15243739088991443,
#   "MAE": 13065.331473214286,
#   "MSE": 172082110.88226318,
#   "RMSE": 13118.007123121377,
#   "MAPE": 0.09373769050304014
# }
# Percent CPU Usage: 46.9
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:48.397185+07:00
# PROGRESS: [ 10818 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 48,
#   "patience_list": 10,
#   "MAE_normalize": 0.09875850219910878,
#   "MSE_normalize": 0.01003917729638015,
#   "RMSE_normalize": 0.10019569499923711,
#   "MAPE_normalize": 0.10242675513070323,
#   "MAE": 8797.60267857143,
#   "MSE": 79666887.68012346,
#   "RMSE": 8925.630940170195,
#   "MAPE": 0.06303647054019766
# }
# Percent CPU Usage: 53.5
# Percent Ram Usage: 18.4
# 2022-10-23 23:09:54.969418+07:00
# PROGRESS: [ 10819 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 52,
#   "patience_list": 10,
#   "MAE_normalize": 0.1737331923639473,
#   "MSE_normalize": 0.030459169469770293,
#   "RMSE_normalize": 0.17452555534869468,
#   "MAPE_normalize": 0.18054113510536468,
#   "MAE": 15476.5,
#   "MSE": 241711853.48643276,
#   "RMSE": 15547.085047893472,
#   "MAPE": 0.11102610879262935
# }
# Percent CPU Usage: 51.7
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:03.353603+07:00
# PROGRESS: [ 10820 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 64,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.10131612899147155,
#   "MSE_normalize": 0.010608901017085401,
#   "RMSE_normalize": 0.10299951949929378,
#   "MAPE_normalize": 0.1050465279239206,
#   "MAE": 9025.440848214286,
#   "MSE": 84187974.44059536,
#   "RMSE": 9175.400505732454,
#   "MAPE": 0.06465657893379048
# }
# Percent CPU Usage: 50.0
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:10.130837+07:00
# PROGRESS: [ 10821 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 58,
#   "patience_list": 10,
#   "MAE_normalize": 0.19674834236601813,
#   "MSE_normalize": 0.038984056638188214,
#   "RMSE_normalize": 0.1974438062796304,
#   "MAPE_normalize": 0.20451918471577876,
#   "MAE": 17526.73214285714,
#   "MSE": 309361858.6647077,
#   "RMSE": 17588.685529757695,
#   "MAPE": 0.12575722222028227
# }
# Percent CPU Usage: 51.0
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:16.697953+07:00
# PROGRESS: [ 10822 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 2,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 128,
#   "n_steps": 3,
#   "last_epoch": 39,
#   "patience_list": 10,
#   "MAE_normalize": 0.09094645349141924,
#   "MSE_normalize": 0.008617503100843731,
#   "RMSE_normalize": 0.09283050738223793,
#   "MAPE_normalize": 0.09424196412718376,
#   "MAE": 8101.689732142857,
#   "MSE": 68385059.78778948,
#   "RMSE": 8269.525971166031,
#   "MAPE": 0.058018943476462075
# }
# Percent CPU Usage: 49.3
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:23.301151+07:00
# PROGRESS: [ 10823 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 20,
#   "patience_list": 10,
#   "MAE_normalize": 0.04503730418525816,
#   "MSE_normalize": 0.002376391774809731,
#   "RMSE_normalize": 0.048748248940959214,
#   "MAPE_normalize": 0.046413567409018086,
#   "MAE": 4012.011160714286,
#   "MSE": 18858096.640171595,
#   "RMSE": 4342.591005398919,
#   "MAPE": 0.02863477939205627
# }
# Percent CPU Usage: 59.4
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:35.247281+07:00
# PROGRESS: [ 10824 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 2,
#   "n_steps": 3,
#   "last_epoch": 16,
#   "patience_list": 10,
#   "MAE_normalize": 0.06139510923297458,
#   "MSE_normalize": 0.004126886796540294,
#   "RMSE_normalize": 0.06424084990518333,
#   "MAPE_normalize": 0.06344804592018692,
#   "MAE": 5469.196428571428,
#   "MSE": 32749304.006417412,
#   "RMSE": 5722.700761565068,
#   "MAPE": 0.039101878075697157
# }
# Percent CPU Usage: 56.8
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:48.085202+07:00
# PROGRESS: [ 10825 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 29,
#   "patience_list": 10,
#   "MAE_normalize": 0.13164731487730966,
#   "MSE_normalize": 0.017514494290034658,
#   "RMSE_normalize": 0.13234233748137691,
#   "MAPE_normalize": 0.13678109625580562,
#   "MAE": 11727.40513392857,
#   "MSE": 138988044.3287092,
#   "RMSE": 11789.319078246597,
#   "MAPE": 0.08412120164018241
# }
# Percent CPU Usage: 47.9
# Percent Ram Usage: 18.4
# 2022-10-23 23:10:59.815273+07:00
# PROGRESS: [ 10826 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 4,
#   "n_steps": 3,
#   "last_epoch": 45,
#   "patience_list": 10,
#   "MAE_normalize": 0.08932640776137336,
#   "MSE_normalize": 0.008264585617223177,
#   "RMSE_normalize": 0.09090976634676373,
#   "MAPE_normalize": 0.0926011474529662,
#   "MAE": 7957.373883928572,
#   "MSE": 65584454.23668562,
#   "RMSE": 8098.42294750562,
#   "MAPE": 0.056999760217893734
# }
# Percent CPU Usage: 61.1
# Percent Ram Usage: 18.4
# 2022-10-23 23:11:15.214191+07:00
# PROGRESS: [ 10827 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 39,
#   "patience_list": 10,
#   "MAE_normalize": 0.12214682836716909,
#   "MSE_normalize": 0.015110090410225584,
#   "RMSE_normalize": 0.12292310771464242,
#   "MAPE_normalize": 0.12687693420245924,
#   "MAE": 10881.083705357143,
#   "MSE": 119907673.37356131,
#   "RMSE": 10950.236224555218,
#   "MAPE": 0.07803796146713371
# }
# Percent CPU Usage: 49.0
# Percent Ram Usage: 18.4
# 2022-10-23 23:11:27.876804+07:00
# PROGRESS: [ 10828 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 8,
#   "n_steps": 3,
#   "last_epoch": 43,
#   "patience_list": 10,
#   "MAE_normalize": 0.08794856976284693,
#   "MSE_normalize": 0.00801680834676578,
#   "RMSE_normalize": 0.08953663131236164,
#   "MAPE_normalize": 0.09116866705829389,
#   "MAE": 7834.630580357143,
#   "MSE": 63618141.73375593,
#   "RMSE": 7976.098152214273,
#   "MAPE": 0.056118971019041876
# }
# Percent CPU Usage: 57.7
# Percent Ram Usage: 18.4
# 2022-10-23 23:11:40.148915+07:00
# PROGRESS: [ 10829 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 41,
#   "patience_list": 10,
#   "MAE_normalize": 0.10022584934418935,
#   "MSE_normalize": 0.010233313002007789,
#   "RMSE_normalize": 0.10115983887891375,
#   "MAPE_normalize": 0.10404238669327644,
#   "MAE": 8928.316964285714,
#   "MSE": 81207463.99839565,
#   "RMSE": 9011.518406927638,
#   "MAPE": 0.06400848815114296
# }
# Percent CPU Usage: 52.7
# Percent Ram Usage: 18.4
# 2022-10-23 23:11:50.461159+07:00
# PROGRESS: [ 10830 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "mul",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 16,
#   "n_steps": 3,
#   "last_epoch": 43,
#   "patience_list": 10,
#   "MAE_normalize": 0.07370879022237627,
#   "MSE_normalize": 0.005722272998964168,
#   "RMSE_normalize": 0.0756457070755781,
#   "MAPE_normalize": 0.0763280835434385,
#   "MAE": 6566.129464285715,
#   "MSE": 45409720.87555803,
#   "RMSE": 6738.673524927442,
#   "MAPE": 0.047002762598346536
# }
# Percent CPU Usage: 53.2
# Percent Ram Usage: 18.4
# 2022-10-23 23:12:00.557535+07:00
# PROGRESS: [ 10831 / 12600 ]
# {
#   "model": "LSTM",
#   "AHB_number": "AHB_1",
#   "Multi_Uni": "uni",
#   "n_layer": 3,
#   "LSTM_hidden_units": 32,
#   "dropouts": 0.2,
#   "n_batch": 32,
#   "n_steps": 3,
#   "last_epoch": 59,
#   "patience_list": 10,
#   "MAE_normalize": 0.11110942757654584,
#   "MSE_normalize": 0.012525605858300093,
#   "RMSE_normalize": 0.11191785317052902,
#   "MAPE_normalize": 0.11538845570142717,
#   "MAE": 9897.847098214286,
#   "MSE": 99398170.89814976,
#   "RMSE": 9969.863133370976,
#   "MAPE": 0.07097735372775629
# }
# Percent CPU Usage: 50.8
# Percent Ram Usage: 18.4
# 2022-10-23 23:12:12.406879+07:00
# PROGRESS: [ 10832 / 12600 ]

# %%
name = "all_performance_LSTM_with_Attention_AHB1"
json.dump(performance_json, open(name + ".json","w"))
df_json = pd.read_json('/content/' + name + '.json')
df_json.to_csv('/content/' + name + '.csv', index=False)
! cp /content/all_performance_LSTM_with_Attention_AHB1.csv /content/drive/MyDrive/Depression

# %%
df_json
